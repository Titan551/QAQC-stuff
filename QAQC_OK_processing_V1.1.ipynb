# %% [markdown]
# <header>
# <h1> <b> Hobo "OK" files processing Script </b> </h1>
# </header>
# This is a script that will handle the Provisional Duplicate files that passed <br>
# Written by Cole Sheeley
# <br>Edited: 6/7/2024: date of file generation

# %% [markdown]
# ## <B> BEFORE YOU START
# <li>This code will process the Provisional Duplicate files marked as OK_ to then be uploaded to the google drive
# <li>Make sure to create a folder named PD_processing to store the Provisional_Duplicate folders downloaded from the google drive

# %% [markdown]
# ## <u>NOTE: If error occurs, it was most likely due to running a previous cell that caused an overwrite of a variable. To fix it, rerun the code from the top!</u>

# %% [markdown]
# ## Importing libraries:
# These are the libaries you will need to run this code. If not previously installed, make sure to use the function pip.install in the console: e.g. pip.install os
# </ol> Below is a list of the libraries and a breif description of what they do.
# <li>os: This module in python provides functions to interact with the operating system such as navigating, accesing environment variables, and executing system commands.
# <li>pandas(pd): pandas is used for data manipulation and analysis library providing data structures like DataFrames and Series, allowing you to work with structured data easily
# <li>glob: provides a way to search for files that match a specified pattern
# <li>matplotlib.pyplot(plt): this is a plotting library that enables the creation of plots and visualizations. The 'pyplot' module provides a MATLAB-like interface for creating plots interactively
# <li>datetime: provides classes for working with dates and times, allowing you to create, manipulate, format, and perform operations on dates and times.

# %%
#%% Imports
import os
import pandas as pd
import glob
import matplotlib.pyplot as plt
from datetime import datetime

# %% [markdown]
# ## <b>Step 1. Downloading the data files
# <li>Make sure to update the folder path!

# %%
#%% Get file paths
 
# Define folder path where your CSV files are located
folder_path = r'C:\UVI\QAQC stuff\PD_processing\Provisional_Duplicates_2024'

# Define pattern to match CSV files
Start_file_name = 'OK_*.csv'  # Corrected the pattern to match CSV files

# Use glob to get a list of file paths matching the pattern set in Start_file_name
csv_files = glob.glob(os.path.join(folder_path, Start_file_name))

# Print file paths
print(csv_files)
# Out:
# ['C:\\UVI\\QAQC stuff\\PD_processing\\Provisional_Duplicates_2024\\OK_BT_TCCB08_2311_2403.csv', 'C:\\UVI\\QAQC stuff\\PD_processing\\Provisional_Duplicates_2024\\OK_BT_TCGB63_2310_2405.csv', 'C:\\UVI\\QAQC stuff\\PD_processing\\Provisional_Duplicates_2024\\OK_BT_TCSR41_2210_2401.csv']

# %% [markdown]
# ## <b>Step 2. Import the .csv files and create dataframes

# %%
#%% Create dataframes
PD_frames = []  # Create an empty list to store dataframes

# Iterate over each file path and read CSV files into dataframes
for file in csv_files:
    df = pd.read_csv(file)
    PD_frames.append(df)  # Append each dataframe to the list
print(PD_frames)
# Out:
# [           # Date Time, GMT-04:00  Temp A  Temp B  Temperature_Difference  \
# 0        310  2023-11-12 13:15:00  29.565  29.515                   0.050
# 1        311  2023-11-12 13:30:00  29.565  29.515                   0.050
# 2        312  2023-11-12 13:45:00  29.565  29.490                   0.075
# 3        313  2023-11-12 14:00:00  29.565  29.490                   0.075
# 4        314  2023-11-12 14:15:00  29.565  29.515                   0.050
# ...      ...                  ...     ...     ...                     ...
# 11695  12005  2024-03-13 09:00:00  27.210  27.112                   0.098
# 11696  12006  2024-03-13 09:15:00  27.235  27.136                   0.099
# 11697  12007  2024-03-13 09:30:00  27.235  27.136                   0.099
# 11698  12008  2024-03-13 09:45:00  27.235  27.136                   0.099
# 11699  12009  2024-03-13 10:00:00  27.235  27.136                   0.099
#
#        Average_temp   Flag
# 0           29.5400  False
# ...

# %% [markdown]
# ## <b>Step 3. Rename, drop columns, and export
# <li>Make sure to change the folder path!
# <li>These files can then be uploaded to their correct site folders on the google drive!
# <li>Make sure when uploading to also include the .hobo, DETAILS_.txt, and DATASET_.txt files with them!

# %%
# %% drop columns and export
# Define the output folder path
output_folder = r'C:\UVI\QAQC stuff\PD_processing\PD_2024_output'

# Rename the Average_temp column to Temperature
for df in PD_frames:
    df.rename(columns={'Average_temp': 'Temperature'}, inplace=True)

# Export the files dropping the OK_ from the naming convention and keeping selected columns
for idx, df in enumerate(PD_frames):
    # Drop 'OK_' from the file name
    file_name = os.path.basename(csv_files[idx])[3:]
    # Select desired columns
    selected_columns = ['#', 'Date Time, GMT-04:00', 'Temperature']
    selected_df = df[selected_columns]
    # Export to a new CSV file in the output folder
    selected_df.to_csv(os.path.join(output_folder, file_name), index=False)
    print(f"File '{file_name}' was exported to {output_folder}")
# Out:
# File 'BT_TCBKPT_2310_2402.csv' was exported to C:\UVI\QAQC stuff\PD_processing\PD_2023_output
# File 'BT_TCCB40_2211_2311.csv' was exported to C:\UVI\QAQC stuff\PD_processing\PD_2023_output
# File 'BT_TCGB63_2212_2310.csv' was exported to C:\UVI\QAQC stuff\PD_processing\PD_2023_output
# File 'BT_TCGMKT_2212_2312.csv' was exported to C:\UVI\QAQC stuff\PD_processing\PD_2023_output
# File 'BT_TCMT40_2210_2311.csv' was exported to C:\UVI\QAQC stuff\PD_processing\PD_2023_output
# File 'BT_TCSHCS_2210_2310.csv' was exported to C:\UVI\QAQC stuff\PD_processing\PD_2023_output
# File 'BT_TCSR99_1910_2101.csv' was exported to C:\UVI\QAQC stuff\PD_processing\PD_2023_output

# %% [markdown]
# ## <b>Step 4. Drop columns, and export for reupload
# Since all of the data files on the google drive need to have the same format, this cell keeps the OK_ naming convention, but drops the additional columns.
# <li>Make sure to update the folder path!
# <li>Then reupload the OK_ files to the drive so that they have the same format.

# %%
# %% drop columns and export
# Define the output folder path
output_folder = r'C:\UVI\QAQC stuff\PD_processing\PD_2024_reupload'

# Rename the Average_temp column to Temperature
for df in PD_frames:
    df.rename(columns={'Average_temp': 'Temperature'}, inplace=True)

# Export the files dropping the OK_ from the naming convention and keeping selected columns
for idx, df in enumerate(PD_frames):
    # Drop 'OK_' from the file name
    file_name = os.path.basename(csv_files[idx])[0:]
    # Select desired columns
    selected_columns = ['#', 'Date Time, GMT-04:00', 'Temperature']
    selected_df = df[selected_columns]
    # Export to a new CSV file in the output folder
    selected_df.to_csv(os.path.join(output_folder, file_name), index=False)
    print(f"File '{file_name}' was exported to {output_folder}")
# Out:
# File 'OK_BT_TCCB08_2311_2403.csv' was exported to C:\UVI\QAQC stuff\PD_processing\PD_2024_reupload
# File 'OK_BT_TCGB63_2310_2405.csv' was exported to C:\UVI\QAQC stuff\PD_processing\PD_2024_reupload
# File 'OK_BT_TCSR41_2210_2401.csv' was exported to C:\UVI\QAQC stuff\PD_processing\PD_2024_reupload
