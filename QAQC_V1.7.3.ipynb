# %% [markdown]
# <header>
# <h1> <b> Hobo Logger SOP Script </b> </h1>
# </header>
# This is a script that will handle the steps outlined in the Hobo Logger SOP. <br>
# Written by Travis Hamlin and Cole Sheeley
# <br>Edited: 3/26/2024: date of file generation

# %% [markdown]
# ## Steps outlined by the SOP
# 1. Downloading and merging the data files
# 2. Checking, processing, and naming the .csv file
# 3. Exporting hobo file details and creating a metadata file
# 4. Create the metadata file
# 5. Upload and update files
# #### NOTE: Although outlined in the SOP, this code in its current version, will not complete steps 3 through 5, so make sure these are completed manually!

# %% [markdown]
# ## <B> BEFORE YOU START
# <li>This code will process the HOBO Logger data after it has been put into '.csv' format.
# <li>This code uses the metadata that is in the Temperature_UVI_deployment_log that is on google drive.
# <li>The Temperature_UVI_deployment_log needs to be downloaded as a '.csv'.
# <li>All of the date columns in the UVI deployment log must be formated as month/day/full year. e.g. 1/1/2024
# <li>All of the time columns in the UVI deployment log must be formatted as hh:mm:ss in military time. e.g. 14:30:00

# %% [markdown]
# ### <b>FILE NAMING: duplicate files should be named _a and _b and offset files should be named _c and _d
# <li>e.g. "BT_TCCB08_2210_a"

# %% [markdown]
# ## <u>NOTE: If error occurs, it was most likely due to running a previous cell that caused an overwrite of a variable. To fix it, rerun the code from the top!</u>

# %% [markdown]
# ## Working log: updates on issues and fixes that we ran into
# There must be either an a or a blank for the files. the code will not process it if there is only a 'b' file. e.g. BT_TFLTC_2310_b had to be changed to _a

# %% [markdown]
# ## Importing libraries:
# These are the libaries you will need to run this code. If not previously installed, make sure to use the function pip.install in the console: e.g. pip.install os
# </ol> Below is a list of the libraries and a breif description of what they do.
# <li>os: This module in python provides functions to interact with the operating system such as navigating, accesing environment variables, and executing system commands.
# <li>pandas(pd): pandas is used for data manipulation and analysis library providing data structures like DataFrames and Series, allowing you to work with structured data easily
# <li>glob: provides a way to search for files that match a specified pattern
# <li>matplotlib.pyplot(plt): this is a plotting library that enables the creation of plots and visualizations. The 'pyplot' module provides a MATLAB-like interface for creating plots interactively
# <li>datetime: provides classes for working with dates and times, allowing you to create, manipulate, format, and perform operations on dates and times.

# %%
#%% Imports
import os
import pandas as pd
import glob
import matplotlib.pyplot as plt
from datetime import datetime

# %% [markdown]
# ## <b>Step 1. Downloading the data files and wrangling

# %% [markdown]
# ### Getting the file paths:
# This cell block accesses the folder path where the .csv files are stored. The lower case r before 'folderpath' is to avoid having to change the backslashes to foward slashes because of using a PC. If using a MAC, you can copy and paste the folderpath and remove the lower case r as foward slashes are default for that operating system.
# <li><u>Make sure to update the folder path in the cell!</u>

# %%
#%% Get file paths
 
# Define folder path where your CSV files are located
folder_path = r'C:\UVI\QAQC stuff\Temp_TCRMP_2021_Working Folder'

# Define pattern to match CSV files
file_pattern = '*.csv'

# Use glob to get a list of file paths matching the pattern set in file_pattern
csv_files = glob.glob(folder_path + '/' + file_pattern)

# Print file paths
print(csv_files)
# Out:
# ['C:\\UVI\\QAQC stuff\\Temp_TCRMP_2021_Working Folder\\BT_TCBKIT_2011.csv', 'C:\\UVI\\QAQC stuff\\Temp_TCRMP_2021_Working Folder\\BT_TCBKIX_2103_a.csv', 'C:\\UVI\\QAQC stuff\\Temp_TCRMP_2021_Working Folder\\BT_TCBKIX_2103_b.csv', 'C:\\UVI\\QAQC stuff\\Temp_TCRMP_2021_Working Folder\\BT_TCBKPT_2011_a.csv', 'C:\\UVI\\QAQC stuff\\Temp_TCRMP_2021_Working Folder\\BT_TCBKPT_2011_b.csv', 'C:\\UVI\\QAQC stuff\\Temp_TCRMP_2021_Working Folder\\BT_TCBOTB_2011.csv', 'C:\\UVI\\QAQC stuff\\Temp_TCRMP_2021_Working Folder\\BT_TCBRWB_2011.csv', 'C:\\UVI\\QAQC stuff\\Temp_TCRMP_2021_Working Folder\\BT_TCCB08_2104_a.csv', 'C:\\UVI\\QAQC stuff\\Temp_TCRMP_2021_Working Folder\\BT_TCCB08_2104_b.csv', 'C:\\UVI\\QAQC stuff\\Temp_TCRMP_2021_Working Folder\\BT_TCCB40_2104_a.csv', 'C:\\UVI\\QAQC stuff\\Temp_TCRMP_2021_Working Folder\\BT_TCCB40_2104_b.csv', 'C:\\UVI\\QAQC stuff\\Temp_TCRMP_2021_Working Folder\\BT_TCCLGE_2012.csv', 'C:\\UVI\\QAQC stuff\\Temp_TCRMP_2021_Working Folder\\BT_TCCORB_2012.csv', 'C:\\UVI\\QAQC stuff\\Temp_TCRMP_2021_Working Folder\\BT_TCCORK_2011_a.csv', 'C:\\UVI\\QAQC stuff\\Temp_TCRMP_2021_Working Folder\\BT_TCCORK_2011_b.csv', 'C:\\UVI\\QAQC stuff\\Temp_TCRMP_2021_Working Folder\\BT_TCCSTL_2104.csv', 'C:\\UVI\\QAQC stuff\\Temp_TCRMP_2021_Working Folder\\BT_TCEAGR_2104.csv', 'C:\\UVI\\QAQC stuff\\Temp_TCRMP_2021_Working Folder\\BT_TCFLTC_2011_a.csv', 'C:\\UVI\\QAQC stuff\\Temp_TCRMP_2021_Working Folder\\BT_TCFLTC_2011_b.csv', 'C:\\UVI\\QAQC stuff\\Temp_TCRMP_2021_Working Folder\\BT_TCFSHB_2012.csv', 'C:\\UVI\\QAQC stuff\\Temp_TCRMP_2021_Working Folder\\BT_TCGMKT_2011_a.csv', 'C:\\UVI\\QAQC stuff\\Temp_TCRMP_2021_Working Folder\\BT_TCGMKT_2011_b.csv', 'C:\\UVI\\QAQC stuff\\Temp_TCRMP_2021_Working Folder\\BT_TCGRPD_2103.csv', 'C:\\UVI\\QAQC stuff\\Temp_TCRMP_2021_Working Folder\\BT_TCHB40_2012_a.csv', 'C:\\UVI\\QAQC stuff\\Temp_TCRMP_2021_Working Folder\\BT_TCHB40_2012_b.csv', 'C:\\UVI\\QAQC stuff\\Temp_TCRMP_2021_Working Folder\\BT_TCJCKB_2104.csv', 'C:\\UVI\\QAQC stuff\\Temp_TCRMP_2021_Working Folder\\BT_TCKNGC_2103.csv', 'C:\\UVI\\QAQC stuff\\Temp_TCRMP_2021_Working Folder\\BT_TCLBEM_2103.csv', 'C:\\UVI\\QAQC stuff\\Temp_TCRMP_2021_Working Folder\\BT_TCLBRH_2103.csv', 'C:\\UVI\\QAQC stuff\\Temp_TCRMP_2021_Working Folder\\BT_TCLSTJ_2011.csv', 'C:\\UVI\\QAQC stuff\\Temp_TCRMP_2021_Working Folder\\BT_TCMAGB_2011.csv', 'C:\\UVI\\QAQC stuff\\Temp_TCRMP_2021_Working Folder\\BT_TCMERI_2012.csv', 'C:\\UVI\\QAQC stuff\\Temp_TCRMP_2021_Working Folder\\BT_TCMT24_2103.csv', 'C:\\UVI\\QAQC stuff\\Temp_TCRMP_2021_Working Folder\\BT_TCMT40_2103_a.csv', 'C:\\UVI\\QAQC stuff\\Temp_TCRMP_2021_Working Folder\\BT_TCMT40_2103_b.csv', 'C:\\UVI\\QAQC stuff\\Temp_TCRMP_2021_Working Folder\\BT_TCSAVA_2011.csv', 'C:\\UVI\\QAQC stuff\\Temp_TCRMP_2021_Working Folder\\BT_TCSC35_2011_a.csv', 'C:\\UVI\\QAQC stuff\\Temp_TCRMP_2021_Working Folder\\BT_TCSC35_2011_b.csv', 'C:\\UVI\\QAQC stuff\\Temp_TCRMP_2021_Working Folder\\BT_TCSCAP_2011_a.csv', 'C:\\UVI\\QAQC stuff\\Temp_TCRMP_2021_Working Folder\\BT_TCSCAP_2011_b.csv', 'C:\\UVI\\QAQC stuff\\Temp_TCRMP_2021_Working Folder\\BT_TCSHCS_2011_a.csv', 'C:\\UVI\\QAQC stuff\\Temp_TCRMP_2021_Working Folder\\BT_TCSHCS_2011_b.csv', 'C:\\UVI\\QAQC stuff\\Temp_TCRMP_2021_Working Folder\\BT_TCSPTH_2103.csv', 'C:\\UVI\\QAQC stuff\\Temp_TCRMP_2021_Working Folder\\BT_TCSR30_2104_.csv', 'C:\\UVI\\QAQC stuff\\Temp_TCRMP_2021_Working Folder\\BT_TCSR41_2104_a.csv', 'C:\\UVI\\QAQC stuff\\Temp_TCRMP_2021_Working Folder\\BT_TCSR41_2104_b.csv', 'C:\\UVI\\QAQC stuff\\Temp_TCRMP_2021_Working Folder\\BT_TCSWAT_2012.csv']

# %% [markdown]
# ### Site codes:
# This cell block contains all of the site codes, and if new ones are created, add them here. If not added, the code will not catch them.
# <h2></ol> <b> MAKE SURE TO ADD NEW SITE CODES TO THE METADATA DOCUMENTS BEFORE ADDING THEM HERE!!! <br>
#  OR ELSE...

# %%
# %% Generate a list of all site codes

site_codes = ["TCCORB","TCFSHB","TCMERI","TCBKPT","TCBOTB","TCBRWB","TCBKIT",
              "TCCORK","TCCLGE","TCFLTC","TCGB63","TCGMKT","TCHB40","TCHB30",
              "TCHB20","TCMAGB","TCSAVA","TCSHCS","TCSCAP","TCSC35","TCSWAT",
              "TCLSTJ","TCBKIX","TCBX33","TCCB08","TCCB40","TCCB99","TCCB67",
              "TCCSTL","TCEAGR","TCGRPD","TCJCKB","TCKNGC","TCLBEM","TCLB99",
              "TCLB67","TCLBRH","TCMT24","TCMT40","TCSR30","TCSR99","TCSR41",
              "TCSR67","TCSR10","TCSPTH"]
## NOTE: site code TCCB60 was not in the site code metadata

# %% [markdown]
# ### Generating dataframes:
# To handle the 'a' and 'b' files, this code generates an empty dictionary to store them that can then be called through a nested dictionary structure. The nested dictonary structure splits the file name by the _ (underscore) to organize each file through a number of identifiers. If the file name does not contain a letter at the end of it, it will be assigned as 'a'. The code then checks the existence of each identifier through a series of if statements in a for loop, by doing nothing if it exists and moving to the next identifier. If the identifier doesn't exist, the else statements create that identifier for the file. The last if and else statement (the middle of the loop), checks if there is two 'a' identifiers for the file; if so then a warning message should appear indicating a duplicate file, if not then adds it to the dictionary. (example for calling a file provided at bottom of the cell)

# %%
#%% Generate dataframes that can be called through a nested dictonary structure
# This creates a nested dictionary that can handle situations when site codes 
# have multiple different start times and multiple files i.e. 'a' and 'b' files

# Create an empty dictionary to store DataFrames structured by site code, file number, file identifier, and file name
df_files = {}

# Iterate through each CSV file
for csv_file in csv_files:
    # Extract site code, file number, file identifier, and file name from the file name
    file_name = os.path.basename(csv_file).split('.')[0]  # Remove the file extension
    parts = file_name.split('_')
    site_code = parts[1]  # Extract the site code
    file_number = parts[2]  # Extract the file number
    file_identifier = parts[-1] if len(parts) > 3 and parts[-1] != '' else "a" # Extract the file identifier ('a', 'b', etc.), assign 'a' if not present
    
    # Read CSV file into a DataFrame
    df = pd.read_csv(csv_file)
    
    # Extract the base file name without the extension
    base_file_name = os.path.splitext(os.path.basename(csv_file))[0]
    
    # Check if the site code already exists in the dictionary
    if site_code in df_files:
        # Check if the file number already exists in the dictionary for the site code
        if file_number in df_files[site_code]:
            # If the file number exists, check if the file identifier already exists
            if file_identifier in df_files[site_code][file_number]:
                print(f"Warning: Duplicate file identifier {file_identifier} for site code {site_code} and file number {file_number}. Ignoring.")
            else:
                # If the file identifier doesn't exist, add the DataFrame and file name to the dictionary
                df_files[site_code][file_number][file_identifier] = {'DataFrame': df, 'File Name': base_file_name}
        else:
            # If the file number doesn't exist, create a new dictionary for the file number
            df_files[site_code][file_number] = {file_identifier: {'DataFrame': df, 'File Name': base_file_name}}
    else:
        # If the site code doesn't exist, create a new dictionary for the site code
        df_files[site_code] = {file_number: {file_identifier: {'DataFrame': df, 'File Name': base_file_name}}}

# Accessing the DataFrames by site code, file number, file identifier, and file name
# For example, to access the DataFrame and file name for site code 'TCBKPT', file number '2209', and file identifier 'a'
if 'TCSR41' in df_files and '2210' in df_files['TCSR41'] and 'a' in df_files['TCSR41']['2210']:
    print("File Name:", df_files['TCSR41']['2210']['a']['File Name'])
    print("DataFrame:")
    print(df_files['TCSR41']['2210']['a']['DataFrame'])
else:
    print("DataFrame not found for site code 'TCSR41', file number '2210', and file identifier 'a'")

print(df_files)
# Out:
# DataFrame not found for site code 'TCSR41', file number '2210', and file identifier 'a'
# {'TCBKIT': {'2011': {'a': {'DataFrame':            # Date Time, GMT-04:00  Temp, °C Coupler Detached Coupler Attached  \
# 0          1    11/05/20 08:00:00    25.186           Logged              NaN
# 1          2    11/05/20 08:15:00    25.258              NaN              NaN
# 2          3    11/05/20 08:30:00    25.355              NaN              NaN
# 3          4    11/05/20 08:45:00    26.573              NaN              NaN
# 4          5    11/05/20 09:00:00    27.727              NaN              NaN
# ...      ...                  ...       ...              ...              ...
# 36298  36299    11/18/21 10:30:00    25.162              NaN              NaN
# 36299  36300    11/18/21 10:45:00    25.939              NaN              NaN
# 36300  36301    11/18/21 11:00:00    26.061              NaN              NaN
# 36301  36302    11/18/21 11:04:25       NaN              NaN           Logged
# 36302  36303    11/18/21 11:04:34       NaN              NaN              NaN
#
#       Host Connected Stopped End Of File
# 0                NaN     NaN         NaN
# 1                NaN     NaN         NaN
# 2                NaN     NaN         NaN
# 3                NaN     NaN         NaN
# 4                NaN     NaN         NaN
# ...              ...     ...         ...
# 36298            NaN     NaN         NaN
# 36299            NaN     NaN         NaN
# 36300            NaN     NaN         NaN
# 36301         Logged     NaN         NaN
# 36302            NaN  Logged      Logged
#
# [36303 rows x 8 columns], 'File Name': 'BT_TCBKIT_2011'}}}, 'TCBKIX': {'2103': {'a': {'DataFrame':            # Date Time, GMT-04:00  Temp, °C Coupler Detached Coupler Attached  \
# 0          1    03/03/21 09:00:00    25.574           Logged              NaN
# 1          2    03/03/21 09:15:00    25.574              NaN              NaN
# 2          3    03/03/21 09:30:00    25.598              NaN              NaN
# 3          4    03/03/21 09:45:00    25.598              NaN              NaN
# 4          5    03/03/21 10:00:00    25.623              NaN              NaN
# ...      ...                  ...       ...              ...              ...
# 26806  26807    12/07/21 14:30:00    27.112              NaN              NaN
# 26807  26808    12/07/21 14:45:00    27.554              NaN              NaN
# 26808  26809    12/07/21 15:00:00    27.776              NaN              NaN
# 26809  26810    12/07/21 15:08:50       NaN              NaN           Logged
# 26810  26811    12/07/21 15:09:02       NaN              NaN              NaN
#
#       Host Connected Stopped End Of File
# 0                NaN     NaN         NaN
# 1                NaN     NaN         NaN
# 2                NaN     NaN         NaN
# 3                NaN     NaN         NaN
# 4                NaN     NaN         NaN
# ...              ...     ...         ...
# 26806            NaN     NaN         NaN
# 26807            NaN     NaN         NaN
# 26808            NaN     NaN         NaN
# 26809         Logged     NaN         NaN
# 26810            NaN  Logged      Logged
#
# [26811 rows x 8 columns], 'File Name': 'BT_TCBKIX_2103_a'}, 'b': {'DataFrame':            # Date Time, GMT-04:00  Temp, °C Coupler Detached Coupler Attached  \
# 0          1
NaN              NaN              NaN
#
#       Host Connected Stopped End Of File
# 0                NaN     NaN         NaN
# 1                NaN     NaN         NaN
# 2                NaN     NaN         NaN
# 3                NaN     NaN         NaN
# 4                NaN     NaN         NaN
# ...              ...     ...         ...
# 34591            NaN     NaN         NaN
# 34592            NaN     NaN         NaN
# 34593            NaN     NaN         NaN
# 34594         Logged     NaN         NaN
# 34595            NaN  Logged      Logged
#
# [34596 rows x 8 columns], 'File Name': 'BT_TCBOTB_2011'}}}, 'TCBRWB': {'2011': {'a': {'DataFrame':            # Date Time, GMT-04:00  Temp, °C Coupler Detached Coupler Attached  \
# 0          1    10/30/20 08:00:00    27.431           Logged              NaN
# 1          2    10/30/20 08:15:00    27.554              NaN              NaN
# 2          3    10/30/20 08:30:00    27.974              NaN              NaN
# 3          4    10/30/20 08:45:00    28.419              NaN              NaN
# 4          5    10/30/20 09:00:00    28.866              NaN              NaN
# ...      ...                  ...       ...              ...              ...
# 35932  35933    11/08/21 15:00:00    27.677              NaN              NaN
# 35933  35934    11/08/21 15:15:00    27.727              NaN              NaN
# 35934  35935    11/08/21 15:30:00    27.924              NaN              NaN
# 35935  35936    11/08/21 15:31:25       NaN              NaN           Logged
# 35936  35937    11/08/21 15:31:34       NaN              NaN              NaN
#
#       Host Connected Stopped End Of File
# 0                NaN     NaN         NaN
# 1                NaN     NaN         NaN
# 2                NaN     NaN         NaN
# 3                NaN     NaN         NaN
# 4                NaN     NaN         NaN
# ...              ...     ...         ...
# 35932            NaN     NaN         NaN
# 35933            NaN     NaN         NaN
# 35934            NaN     NaN         NaN
# 35935         Logged     NaN         NaN
# 35936            NaN  Logged      Logged
#
# [35937 rows x 8 columns], 'File Name': 'BT_TCBRWB_2011'}}}, 'TCCB08': {'2104': {'a': {'DataFrame':            # Date Time, GMT-04:00  Temp, °C Coupler Detached Coupler Attached  \
# 0          1    04/06/21 08:00:00    25.089           Logged              NaN
# 1          2    04/06/21 08:15:00    25.210              NaN              NaN
# 2          3    04/06/21 08:30:00    25.331              NaN              NaN
# 3          4    04/06/21 08:45:00    25.428              NaN              NaN
# 4          5    04/06/21 09:00:00    25.525              NaN              NaN
# ...      ...                  ...       ...              ...              ...
# 23543  23544    12/07/21 13:45:00    27.505              NaN              NaN
# 23544  23545    12/07/21 14:00:00    27.776              NaN              NaN
# 23545  23546    12/07/21 14:15:00    28.023              NaN              NaN
# 23546  23547    12/07/21 14:19:25       NaN              NaN           Logged
# 23547  23548    12/07/21 14:21:51       NaN              NaN              NaN
#
#       Host Connected Stopped End Of File
# 0                NaN     NaN         NaN
# 1                NaN     NaN         NaN
# 2                NaN     NaN         NaN
# 3                NaN     NaN         NaN
# 4                NaN     NaN         NaN
# ...              ...     ...         ...
# 23543            NaN     NaN         NaN
# 23544            NaN     NaN         NaN
# 23545            NaN     NaN         NaN
# 23546         Logged     NaN         NaN
# 23547            NaN  Logged      Logged
#
# [23548 rows x 8 columns], 'File Name': 'BT_TCCB08_2104_a'}, 'b': {'DataFrame':            # Date Time, GMT-04:00  Temp, °C Coupler Detached Coupler Attached  \
# 0          1    04/06/21 08:00:00    25.113           Logged              NaN
# 1          2    04/06/21 08:15:00    25.210              NaN              NaN
# 2          3    04/06/21 08:30:00    25.331              NaN              NaN
# 3          4    04/06/21 08:45:00    25.404              NaN              NaN
# 4          5    04/06/21 09:00:00    25.501              NaN              NaN
# ...      ...                  ...       ...              ...              ...
# 23546  23547    12/07/21 14:30:00    28.048              NaN              NaN
# 23547  23548    12/07/21 14:45:00    28.023              NaN              NaN
# 23548  23549    12/07/21 15:00:00    27.825              NaN              NaN
# 23549  23550    12/07/21 15:03:38       NaN              NaN           Logged
# 23550  23551    12/07/21 15:04:14       NaN              NaN              NaN
#
#       Host Connected Stopped End Of File
# 0                NaN     NaN         NaN
# 1                NaN     NaN         NaN
# 2                NaN     NaN         NaN
# 3                NaN     NaN         NaN
# 4                NaN     NaN         NaN
# ...              ...     ...         ...
# 23546            NaN     NaN         NaN
# 23547            NaN     NaN         NaN
# 23548            NaN     NaN         NaN
# 23549         Logged     NaN         NaN
# 23550            NaN  Logged      Logged
#
# [23551 rows x 8 columns], 'File Name': 'BT_TCCB08_2104_b'}}}, 'TCCB40': {'2104': {'a': {'DataFrame':            # Date Time, GMT-04:00  Temp, °C Coupler Detached Coupler Attached  \
# 0          1    04/06/21 08:00:00    25.065           Logged              NaN
# 1          2    04/06/21 08:15:00    25.186              NaN              NaN
# 2          3    04/06/21 08:30:00    25.307              NaN              NaN
# 3          4    04/06/21 08:45:00    25.404              NaN              NaN
# 4          5    04/06/21 09:00:00    25.501              NaN              NaN
# ...      ...                  ...       ...              ...              ...
# 
NaN              NaN              NaN
#
#       Host Connected Stopped End Of File
# 0                NaN     NaN         NaN
# 1                NaN     NaN         NaN
# 2                NaN     NaN         NaN
# 3                NaN     NaN         NaN
# 4                NaN     NaN         NaN
# ...              ...     ...         ...
# 23537            NaN     NaN         NaN
# 23538            NaN     NaN         NaN
# 23539            NaN     NaN         NaN
# 23540         Logged     NaN         NaN
# 23541            NaN  Logged      Logged
#
# [23542 rows x 8 columns], 'File Name': 'BT_TCEAGR_2104'}}}, 'TCFLTC': {'2011': {'a': {'DataFrame':            # Date Time, GMT-04:00  Temp, °C Coupler Detached Coupler Attached  \
# 0          1    10/30/20 08:00:00    27.481           Logged              NaN
# 1          2    10/30/20 08:15:00    27.776              NaN              NaN
# 2          3    10/30/20 08:30:00    28.171              NaN              NaN
# 3          4    10/30/20 08:45:00    28.642              NaN              NaN
# 4          5    10/30/20 09:00:00    29.140              NaN              NaN
# ...      ...                  ...       ...              ...              ...
# 35991  35992    11/09/21 05:45:00    28.965              NaN              NaN
# 35992  35993    11/09/21 06:00:00    29.966              NaN              NaN
# 35993  35994    11/09/21 06:15:00    29.941              NaN              NaN
# 35994  35995    11/09/21 06:22:08       NaN              NaN           Logged
# 35995  35996    11/09/21 06:22:19       NaN              NaN              NaN
#
#       Host Connected Stopped End Of File
# 0                NaN     NaN         NaN
# 1                NaN     NaN         NaN
# 2                NaN     NaN         NaN
# 3                NaN     NaN         NaN
# 4                NaN     NaN         NaN
# ...              ...     ...         ...
# 35991            NaN     NaN         NaN
# 35992            NaN     NaN         NaN
# 35993            NaN     NaN         NaN
# 35994         Logged     NaN         NaN
# 35995            NaN  Logged      Logged
#
# [35996 rows x 8 columns], 'File Name': 'BT_TCFLTC_2011_a'}, 'b': {'DataFrame':            # Date Time, GMT-04:00  Temp, °C Coupler Detached Coupler Attached  \
# 0          1    10/30/20 08:00:00    27.456           Logged              NaN
# 1          2    10/30/20 08:15:00    27.628              NaN              NaN
# 2          3    10/30/20 08:30:00    28.023              NaN              NaN
# 3          4    10/30/20 08:45:00    28.518              NaN              NaN
# 4          5    10/30/20 09:00:00    29.040              NaN              NaN
# ...      ...                  ...       ...              ...              ...
# 36009  36010    11/09/21 09:15:00    28.493              NaN              NaN
# 36010  36011    11/09/21 09:30:00    27.554              NaN              NaN
# 36011  36012    11/09/21 09:45:00    27.038              NaN              NaN
# 36012  36013    11/09/21 09:54:56       NaN              NaN           Logged
# 36013  36014    11/09/21 09:55:03       NaN              NaN              NaN
#
#       Host Connected Stopped End Of File
# 0                NaN     NaN         NaN
# 1                NaN     NaN         NaN
# 2                NaN     NaN         NaN
# 3                NaN     NaN         NaN
# 4                NaN     NaN         NaN
# ...              ...     ...         ...
# 36009            NaN     NaN         NaN
# 36010            NaN     NaN         NaN
# 36011            NaN     NaN         NaN
# 36012         Logged     NaN         NaN
# 36013            NaN  Logged      Logged
#
# [36014 rows x 8 columns], 'File Name': 'BT_TCFLTC_2011_b'}}}, 'TCFSHB': {'2012': {'a': {'DataFrame':            # Date Time, GMT-04:00  Temp, °C Coupler Detached Coupler Attached  \
# 0          1    12/07/20 08:00:00    24.171           Logged              NaN
# 1          2    12/07/20 08:15:00    24.243              NaN              NaN
# 2          3    12/07/20 08:30:00    24.363              NaN              NaN
# 3          4    12/07/20 08:45:00    24.484              NaN              NaN
# 4          5    12/07/20 09:00:00    24.581              NaN              NaN
# ...      ...                  ...       ...              ...              ...
# 32339  32340    11/09/21 04:45:00    28.766              NaN              NaN
# 32340  32341    11/09/21 05:00:00    28.791              NaN              NaN
# 32341  32342    11/09/21 05:15:00    28.717              NaN              NaN
# 32342  32343    11/09/21 05:26:44       NaN              NaN           Logged
# 32343  32344    11/09/21 05:27:17       NaN              NaN              NaN
#
#       Host Connected Stopped End Of File
# 0                NaN     NaN         NaN
# 1                NaN     NaN         NaN
# 2                NaN     NaN         NaN
# 3                NaN     NaN         NaN
# 4                NaN     NaN         NaN
# ...              ...     ...         ...
# 32339            NaN     NaN         NaN
# 32340            NaN     NaN         NaN
# 32341            NaN     NaN         NaN
# 32342         Logged     NaN         NaN
# 32343            NaN  Logged      Logged
#
# [32344 rows x 8 columns], 'File Name': 'BT_TCFSHB_2012'}}}, 'TCGMKT': {'2011': {'a': {'DataFrame':            # Date Time, GMT-04:00  Temp, °C Coupler Detached Coupler Attached  \
# 0          1    11/30/20 08:00:00    26.158           Logged              NaN
# 1          2    11/30/20 08:15:00    26.158              NaN              NaN
# 2          3    11/30/20 08:30:00    26.158              NaN              NaN
# 3          4    11/30/20 08:45:00    26.182              NaN              NaN
# 4          5    11/30/20 09:00:00    26.207              NaN              NaN
# ...      ...                  ...       ...              ...              ...
#
NaN              NaN              NaN
#
#       Host Connected Stopped End Of File
# 0                NaN     NaN         NaN
# 1                NaN     NaN         NaN
# 2                NaN     NaN         NaN
# 3                NaN     NaN         NaN
# 4                NaN     NaN         NaN
# ...              ...     ...         ...
# 39959            NaN     NaN         NaN
# 39960         Logged     NaN         NaN
# 39961            NaN     NaN         NaN
# 39962         Logged     NaN         NaN
# 39963            NaN  Logged      Logged
#
# [39964 rows x 8 columns], 'File Name': 'BT_TCSC35_2011_b'}}}, 'TCSCAP': {'2011': {'a': {'DataFrame':            # Date Time, GMT-04:00  Temp, °C Coupler Detached Coupler Attached  \
# 0          1    11/30/20 08:00:00    26.182           Logged              NaN
# 1          2    11/30/20 08:15:00    26.182              NaN              NaN
# 2          3    11/30/20 08:30:00    26.182              NaN              NaN
# 3          4    11/30/20 08:45:00    26.207              NaN              NaN
# 4          5    11/30/20 09:00:00    26.231              NaN              NaN
# ...      ...                  ...       ...              ...              ...
# 33904  33905    11/18/21 12:00:00    28.023              NaN              NaN
# 33905  33906    11/18/21 12:15:00    28.023              NaN              NaN
# 33906  33907    11/18/21 12:23:32       NaN              NaN           Logged
# 33907  33908    11/18/21 12:23:33       NaN              NaN              NaN
# 33908  33909    11/18/21 12:23:40       NaN              NaN              NaN
#
#       Host Connected Stopped End Of File
# 0                NaN     NaN         NaN
# 1                NaN     NaN         NaN
# 2                NaN     NaN         NaN
# 3                NaN     NaN         NaN
# 4                NaN     NaN         NaN
# ...              ...     ...         ...
# 33904            NaN     NaN         NaN
# 33905            NaN     NaN         NaN
# 33906            NaN     NaN         NaN
# 33907         Logged     NaN         NaN
# 33908            NaN  Logged      Logged
#
# [33909 rows x 8 columns], 'File Name': 'BT_TCSCAP_2011_a'}, 'b': {'DataFrame':            # Date Time, GMT-04:00  Temp, °C Coupler Detached Coupler Attached  \
# 0          1    11/30/20 08:00:00    26.134           Logged              NaN
# 1          2    11/30/20 08:15:00    26.134              NaN              NaN
# 2          3    11/30/20 08:30:00    26.134              NaN              NaN
# 3          4    11/30/20 08:45:00    26.134              NaN              NaN
# 4          5    11/30/20 09:00:00    26.158              NaN              NaN
# ...      ...                  ...       ...              ...              ...
# 33903  33904    11/18/21 11:45:00    28.048              NaN              NaN
# 33904  33905    11/18/21 12:00:00    27.974              NaN              NaN
# 33905  33906    11/18/21 12:15:00    28.048              NaN              NaN
# 33906  33907    11/18/21 12:23:43       NaN              NaN           Logged
# 33907  33908    11/18/21 12:23:49       NaN              NaN              NaN
#
#       Host Connected Stopped End Of File
# 0                NaN     NaN         NaN
# 1                NaN     NaN         NaN
# 2                NaN     NaN         NaN
# 3                NaN     NaN         NaN
# 4                NaN     NaN         NaN
# ...              ...     ...         ...
# 33903            NaN     NaN         NaN
# 33904            NaN     NaN         NaN
# 33905            NaN     NaN         NaN
# 33906         Logged     NaN         NaN
# 33907            NaN  Logged      Logged
#
# [33908 rows x 8 columns], 'File Name': 'BT_TCSCAP_2011_b'}}}, 'TCSHCS': {'2011': {'a': {'DataFrame':            # Date Time, GMT-04:00  Temp, °C Coupler Detached Coupler Attached  \
# 0          1    11/30/20 08:00:00    26.158           Logged              NaN
# 1          2    11/30/20 08:15:00    26.158              NaN              NaN
# 2          3    11/30/20 08:30:00    26.158              NaN              NaN
# 3          4    11/30/20 08:45:00    26.158              NaN              NaN
# 4          5    11/30/20 09:00:00    26.182              NaN              NaN
# ...      ...                  ...       ...              ...              ...
# 33902  33903    11/18/21 11:30:00    27.407              NaN              NaN
# 33903  33904    11/18/21 11:45:00    27.382              NaN              NaN
# 33904  33905    11/18/21 12:00:00    27.456              NaN              NaN
# 33905  33906    11/18/21 12:14:51       NaN              NaN           Logged
# 33906  33907    11/18/21 12:14:58       NaN              NaN              NaN
#
#       Host Connected Stopped End Of File
# 0                NaN     NaN         NaN
# 1                NaN     NaN         NaN
# 2                NaN     NaN         NaN
# 3                NaN     NaN         NaN
# 4                NaN     NaN         NaN
# ...              ...     ...         ...
# 33902            NaN     NaN         NaN
# 33903            NaN     NaN         NaN
# 33904            NaN     NaN         NaN
# 33905         Logged     NaN         NaN
# 33906            NaN  Logged      Logged
#
# [33907 rows x 8 columns], 'File Name': 'BT_TCSHCS_2011_a'}, 'b': {'DataFrame':            # Date Time, GMT-04:00  Temp, °C Coupler Detached Coupler Attached  \
# 0          1    11/30/20 08:00:00    26.134           Logged              NaN
# 1          2    11/30/20 08:15:00    26.134              NaN              NaN
# 2          3    11/30/20 08:30:00    26.134              NaN              NaN
# 3          4    11/30/20 08:45:00    26.158              NaN              NaN
# 4          5    11/30/20 09:00:00    26.158              NaN              NaN
# ...      ...                  ...       ...              ...              ...
#
{'DataFrame':            # Date Time, GMT-04:00  Temp, °C Coupler Detached Coupler Attached  \
# 0          1    04/06/21 08:00:00    24.388           Logged              NaN
# 1          2    04/06/21 08:15:00    24.436              NaN              NaN
# 2          3    04/06/21 08:30:00    24.460              NaN              NaN
# 3          4    04/06/21 08:45:00    24.508              NaN              NaN
# 4          5    04/06/21 09:00:00    24.532              NaN              NaN
# ...      ...                  ...       ...              ...              ...
# 23545  23546    12/07/21 14:15:00    26.793              NaN              NaN
# 23546  23547    12/07/21 14:30:00    27.063              NaN              NaN
# 23547  23548    12/07/21 14:45:00    27.530              NaN              NaN
# 23548  23549    12/07/21 14:50:18       NaN              NaN           Logged
# 23549  23550    12/07/21 14:59:56       NaN              NaN              NaN
#
#       Host Connected Stopped End Of File
# 0                NaN     NaN         NaN
# 1                NaN     NaN         NaN
# 2                NaN     NaN         NaN
# 3                NaN     NaN         NaN
# 4                NaN     NaN         NaN
# ...              ...     ...         ...
# 23545            NaN     NaN         NaN
# 23546            NaN     NaN         NaN
# 23547            NaN     NaN         NaN
# 23548         Logged     NaN         NaN
# 23549            NaN  Logged      Logged
#
# [23550 rows x 8 columns], 'File Name': 'BT_TCSR41_2104_b'}}}, 'TCSWAT': {'2012': {'a': {'DataFrame':            # Date Time, GMT-04:00  Temp, °C Coupler Detached Coupler Attached  \
# 0          1    12/02/20 08:00:00    22.369           Logged              NaN
# 1          2    12/02/20 08:15:00    22.561              NaN              NaN
# 2          3    12/02/20 08:30:00    22.968              NaN              NaN
# 3          4    12/02/20 08:45:00    23.545              NaN              NaN
# 4          5    12/02/20 09:00:00    23.905              NaN              NaN
# ...      ...                  ...       ...              ...              ...
# 33705  33706    11/18/21 10:15:00    24.726              NaN              NaN
# 33706  33707    11/18/21 10:30:00    25.307              NaN              NaN
# 33707  33708    11/18/21 10:35:57       NaN              NaN           Logged
# 33708  33709    11/18/21 10:35:58       NaN              NaN              NaN
# 33709  33710    11/18/21 10:36:10       NaN              NaN              NaN
#
#       Host Connected Stopped End Of File
# 0                NaN     NaN         NaN
# 1                NaN     NaN         NaN
# 2                NaN     NaN         NaN
# 3                NaN     NaN         NaN
# 4                NaN     NaN         NaN
# ...              ...     ...         ...
# 33705            NaN     NaN         NaN
# 33706            NaN     NaN         NaN
# 33707            NaN     NaN         NaN
# 33708         Logged     NaN         NaN
# 33709            NaN  Logged      Logged
#
# [33710 rows x 8 columns], 'File Name': 'BT_TCSWAT_2012'}}}}

# %% [markdown]
# ## File identifier check:
# This cell reports all the files that have an 'a' identifier that is assigned when imported. If there is a file without an 'a' identifier, that means there is only a 'b' file and will not be processed by the code. <u> This file needs to then be changed to 'a' so the code can process it.<u>

# %%
for site_code, site_data in df_files.items():
    for file_number, file_data in site_data.items():
        if 'a' not in file_data:
            print(f"Warning: No 'a' identifier found for site code {site_code} and file number {file_number}.")
        else:
            file_name = file_data['a']['File Name']
            print(f"File with 'a' identifier found for site code {site_code} and file number {file_number}: {file_name}")
# Out:
# File with 'a' identifier found for site code TCBKIT and file number 2011: BT_TCBKIT_2011
# File with 'a' identifier found for site code TCBKIX and file number 2103: BT_TCBKIX_2103_a
# File with 'a' identifier found for site code TCBKPT and file number 2011: BT_TCBKPT_2011_a
# File with 'a' identifier found for site code TCBOTB and file number 2011: BT_TCBOTB_2011
# File with 'a' identifier found for site code TCBRWB and file number 2011: BT_TCBRWB_2011
# File with 'a' identifier found for site code TCCB08 and file number 2104: BT_TCCB08_2104_a
# File with 'a' identifier found for site code TCCB40 and file number 2104: BT_TCCB40_2104_a
# File with 'a' identifier found for site code TCCLGE and file number 2012: BT_TCCLGE_2012
# File with 'a' identifier found for site code TCCORB and file number 2012: BT_TCCORB_2012
# File with 'a' identifier found for site code TCCORK and file number 2011: BT_TCCORK_2011_a
# File with 'a' identifier found for site code TCCSTL and file number 2104: BT_TCCSTL_2104
# File with 'a' identifier found for site code TCEAGR and file number 2104: BT_TCEAGR_2104
# File with 'a' identifier found for site code TCFLTC and file number 2011: BT_TCFLTC_2011_a
# File with 'a' identifier found for site code TCFSHB and file number 2012: BT_TCFSHB_2012
# File with 'a' identifier found for site code TCGMKT and file number 2011: BT_TCGMKT_2011_a
# File with 'a' identifier found for site code TCGRPD and file number 2103: BT_TCGRPD_2103
# File with 'a' identifier found for site code TCHB40 and file number 2012: BT_TCHB40_2012_a
# File with 'a' identifier found for site code TCJCKB and file number 2104: BT_TCJCKB_2104
# File with 'a' identifier found for site code TCKNGC and file number 2103: BT_TCKNGC_2103
# File with 'a' identifier found for site code TCLBEM and file number 2103: BT_TCLBEM_2103
# File with 'a' identifier found for site code TCLBRH and file number 2103: BT_TCLBRH_2103
# File with 'a' identifier found for site code TCLSTJ and file number 2011: BT_TCLSTJ_2011
# File with 'a' identifier found for site code TCMAGB and file number 2011: BT_TCMAGB_2011
# File with 'a' identifier found for site code TCMERI and file number 2012: BT_TCMERI_2012
# File with 'a' identifier found for site code TCMT24 and file number 2103: BT_TCMT24_2103
# File with 'a' identifier found for site code TCMT40 and file number 2103: BT_TCMT40_2103_a
# File with 'a' identifier found for site code TCSAVA and file number 2011: BT_TCSAVA_2011
# File with 'a' identifier found for site code TCSC35 and file number 2011: BT_TCSC35_2011_a
# File with 'a' identifier found for site code TCSCAP and file number 2011: BT_TCSCAP_2011_a
# File with 'a' identifier found for site code TCSHCS and file number 2011: BT_TCSHCS_2011_a
# File with 'a' identifier found for site code TCSPTH and file number 2103: BT_TCSPTH_2103
# File with 'a' identifier found for site code TCSR30 and file number 2104: BT_TCSR30_2104_
# File with 'a' identifier found for site code TCSR41 and file number 2104: BT_TCSR41_2104_a
# File with 'a' identifier found for site code TCSWAT and file number 2012: BT_TCSWAT_2012

# %% [markdown]
# ### Read in deployment log:
# The importance of reading in the deployment log is to make sure that the .csv files from the working folder match the loggers that have been deployed and import the metadata for each logger in the working folder, so that they can be called without having to search the deployment log. Make sure to download Temperature_UVI_deployment_log from the google drive as a .csv file.
# <li><u>Make sure to update the folder path in the cell!</u>

# %%
# %% Read in deployment log metadata sheet

deployment_df = pd.read_csv(r'C:\UVI\QAQC stuff\Temperature_UVI_deployment_log.csv')

# %% [markdown]
# ### Filtering the deployment log:
# The cell takes the file names imported from the working folder and uses them to filter out the uncessary files that do not match those imported.

# %%
# %% Filter deployment log metatdata sheet csv

# Extract file names from csv_files
csv_file_names = [os.path.basename(csv_file).split('.')[0] for csv_file in csv_files]

# Filter deployment_df to only include entries that match the file names in csv_files
filtered_deployment_df = deployment_df[deployment_df['Offloaded Filename'].isin(csv_file_names)]

# Print the filtered DataFrame
print(filtered_deployment_df)
# Out:
#       Status                           Location    Logger Tag I.D.  \
# 664  Removed                        Brewers Bay  20925881      NaN
# 665  Removed                       Black Point   20925884      NaN
# 666  Removed            Black Point (duplicate)  20925876      NaN
# 667  Removed                          Flat Cay   20925887      NaN
# 668  Removed               Flat Cay (duplicate)  20925874      NaN
# 670  Removed                  Buck Island (STT)  20925873      NaN
# 671  Removed                   Little St. James  20925880      NaN
# 672  Removed                       Coculus Rock  20925878      NaN
# 673  Removed           Coculus Rock (duplicate)  20925885      NaN
# 674  Removed                         Magens Bay  20925866      NaN
# 675  Removed                         Botany Bay  20925868      NaN
# 676  Removed                             Savana  20925870      NaN
# 677  Removed                      South Capella  20925869      NaN
# 678  Removed          South Capella (duplicate)  20925875      NaN
# 679  Removed                          Seahorse   20719646      NaN
# 680  Removed               Seahorse (duplicate)  20733089      NaN
# 681  Removed                     Grammank Tiger  20925871      NaN
# 682  Removed        Grammanik Tiger (duplicate)  20925865      NaN
# 683  Removed                South Capella 35 m   20925883      NaN
# 684  Removed     South Capella 35 m (duplicate)  20925877      NaN
# 685  Removed                       South Water   20733086      NaN
# 686  Removed                         Hind Bank   20733092      NaN
# 687  Removed             Hind Bank (duplicate)   20733076      NaN
# 688  Removed                 College Shoal East  20925867      NaN
# 689  Removed                   Meri Shoal (STJ)  20925879      NaN
# 690  Removed                    Coral Bay (STJ)  20925888      NaN
# 691  Removed                     Fish Bay (STJ)  20925872      NaN
# 692  Removed              Buck Island MCE (STX)  20954390      NaN
# 693  Removed  Buck Island MCE (STX) (duplicate)  20962639      NaN
# 694  Removed                    Jacks Bay (STX)  20962621      NaN
# 695  Removed                       Castle (STX)  20954392      NaN
# 696  Removed                    Eagle Ray (STX)  20962623      NaN
# 697  Removed                 Kings Corner (STX)  20954384      NaN
# 698  Removed                   Sprat Hole (STX)  20962625      NaN
# 699  Removed                   Mutton 24m (STX)  20954387      NaN
# 700  Removed                   Mutton 39m (STX)  20954386      NaN
# 701  Removed       Mutton 39m (STX) (duplicate)  20962627      NaN
# 702  Removed                      Cane 09 (STX)  20954393      NaN
# 703  Removed          Cane 09 (STX) (duplicate)  20954389      NaN
# 704  Removed                      Cane 39 (STX)  20962624      NaN
# 705  Removed          Cane 39 (STX) (duplicate)  20962629      NaN
# 706  Removed                Salt River 30 (STX)  20954395      NaN
# 707  Removed                Salt River 40 (STX)  20962622      NaN
# 708  Removed    Salt River 40 (STX) (duplicate)  20954383      NaN
# 709  Removed                    Lang Hind (STX)  20733075      NaN
# 710  Removed                   Great Pond (STX)  20719643      NaN
# 711  Removed                    Lang EEMP (STX)  20954396      NaN
#
#         Date On Frequency Duration (d)     Date In   Time In  Date Full  \
# 664  10/30/2020        15          453   11/5/2020  15:27:00  1/14/2022
# 665  10/30/2020        15          453  10/30/2020  13:51:00   1/8/2022
# 666  10/30/2020        15          453  10/30/2020  13:51:00   1/8/2022
# 667  10/30/2020        15          453  10/30/2020  10:51:00   1/8/2022
# 668  10/30/2020        15          453  10/30/2020  10:51:00   1/8/2022
# 670   11/5/2020        15          453   11/5/2020  15:58:00  1/14/2022
# 707      12/7/2021   BT_TCSR41_2104_a  11/13/2021  11:44:00
# 708      12/7/2021   BT_TCSR41_2104_b  11/13/2021  11:44:00
# 709      12/7/2021     BT_TCLBRH_2103  11/22/2021   9:32:00
# 710      12/7/2021     BT_TCGRPD_2103  11/14/2021  13:47:00
# 711      12/7/2021     BT_TCLBEM_2103  11/14/2021  10:35:00
#
#                                                  Notes Unnamed: 15
# 664                                Temps averaged- ENH         NaN
# 665                                Temps averaged- ENH         NaN
# 666                                Temps averaged- ENH         NaN
# 667                                Temps averaged- ENH         NaN
# 668                                                NaN         NaN
# 670                                                NaN         NaN
# 671                                                NaN         NaN
# 672                                Temps averaged- ENH         NaN
# 673                                Temps averaged- ENH         NaN
# 674                                                NaN         NaN
# 675                                                NaN         NaN
# 676                                                NaN         NaN
# 677                                                NaN         NaN
# 678                                                NaN         NaN
# 679                                                NaN         NaN
# 680                                                NaN         NaN
# 681                                Temps averaged- ENH         NaN
# 682                                Temps averaged- ENH         NaN
# 683                                                NaN         NaN
# 684                                                NaN         NaN
# 685                                                NaN         NaN
# 686  Moved from ADCP base to beginning of T1; Temps...         NaN
# 687  Moved from ADCP base to beginning of T1; Temps...         NaN
# 688                                                NaN         NaN
# 689                                                NaN         NaN
# 690                                                NaN         NaN
# 691                                                NaN         NaN
# 692                                                NaN         NaN
# 693                                                NaN         NaN
# 694                                                NaN         NaN
# 695                                                NaN         NaN
# 696                                                NaN         NaN
# 697                                                NaN         NaN
# 698                                                NaN         NaN
# 699                                                NaN         NaN
# 700                                                NaN         NaN
# 701                                                NaN         NaN
# 702                                                NaN         NaN
# 703                                                NaN         NaN
# 704                                                NaN         NaN
# 705                                                NaN         NaN
# 706                                                NaN         NaN
# 707                                                NaN         NaN
# 708                                                NaN         NaN
# 709                                                NaN         NaN
# 710                                                NaN         NaN
# 711                                                NaN         NaN

# %% [markdown]
# ### Warning check 1: unmatched files
# If there are names in the .csv files imported from the working folder that do not match those in the deployment log, the cell below will report a warning and the file(s) that does not match. This may occur from manipulating the names in the working folder, and need to be fixed or the working folder may need to be redownloaded.

# %%
# %% Find which file names you are processing did not match with the file names in the deployment log.


# Extract file names from csv_files
csv_file_names = [os.path.basename(csv_file).split('.')[0] for csv_file in csv_files]

# Filter deployment_df to only include entries that match the file names in csv_files
matched_files = deployment_df[deployment_df['Offloaded Filename'].isin(csv_file_names)]['Offloaded Filename'].tolist()

# Identify files in csv_files that did not match
unmatched_files = [file_name for file_name in csv_file_names if file_name not in matched_files]

# Print files in csv_files that did not match
print("!!!!!WARNING CHECK:!!!!!")
print("Files in csv_files that did not match:")
print(unmatched_files)
# These file names need to be fixed in the google sheet version and the sheet 
# needs to be redownloaded and the code needs to be run again.
# Out:
# !!!!!WARNING CHECK:!!!!!
# Files in csv_files that did not match:
# []

# %% [markdown]
# ### Subsetting column names:
# Filters the columns from the deployment log needed for the metadata of each logger.

# %%
# %% Subset columns from filtered_deployment_df

# 693   BT_TCBKIX_2103_b   3/15/2021  10:30:00  5/24/2022  11/15/2021  10:12:00
# 694     BT_TCJCKB_2104    4/7/2021  10:25:00  6/16/2022  11/11/2021  12:11:00
# 695     BT_TCCSTL_2104    4/7/2021  12:30:00  6/16/2022  11/14/2021  15:41:00
# 696     BT_TCEAGR_2104    4/7/2021  14:45:00  6/16/2022  11/15/2021  15:02:00
# 697     BT_TCKNGC_2103   3/14/2021  12:48:00  5/23/2022  11/12/2021  13:38:00
# 698     BT_TCSPTH_2103   3/14/2021  14:45:00  5/23/2022  11/12/2021  15:29:00
# 699     BT_TCMT24_2103   3/14/2021  10:46:00  5/23/2022  11/12/2021  11:04:00
# 700   BT_TCMT40_2103_a   3/14/2021  10:45:00  5/23/2022  11/12/2021  10:56:00
# 701   BT_TCMT40_2103_b   3/14/2021  10:45:00  5/23/2022  11/12/2021  10:56:00
# 702   BT_TCCB08_2104_a    4/6/2021  11:33:00  6/15/2022  11/16/2021  12:03:00
# 703   BT_TCCB08_2104_b    4/6/2021  11:33:00  6/15/2022  11/16/2021  12:03:00
# 704   BT_TCCB40_2104_a    4/6/2021  10:38:00  6/15/2022  11/16/2021  11:03:00
# 705   BT_TCCB40_2104_b    4/6/2021  10:38:00  6/15/2022  11/16/2021  11:03:00
# 706    BT_TCSR30_2104_    4/8/2021   9:55:00  6/17/2022  11/13/2021  11:37:00
# 707   BT_TCSR41_2104_a    4/8/2021   9:55:00  6/17/2022  11/13/2021  11:44:00
# 708   BT_TCSR41_2104_b    4/8/2021   9:55:00  6/17/2022  11/13/2021  11:44:00
# 709     BT_TCLBRH_2103   3/12/2021  10:53:00  5/21/2022  11/22/2021   9:32:00
# 710     BT_TCGRPD_2103   3/13/2021  13:51:00  5/22/2022  11/14/2021  13:47:00
# 711     BT_TCLBEM_2103   3/13/2021  10:00:00  5/22/2022  11/14/2021  10:35:00

# %% [markdown]
# ### Warning check 2: ? in the time columns
# In the deployment log, it was discovered that there were occasional question marks in the time in and time out columns. This cell identifies those areas that would need to be changed manually in the deployment log. If you run the cell and get "SyntaxWarning..." do not worry, as long as there is a check mark at the bottom left of the cell that means it worked.

# %%
#%% Check to see if there is a "?" in the "Time In" or the "Time Out" Columns
# May want to expand this to account for other instances of Incorrect metadata inputs
# Convert columns to strings
filtered_deployment_df['Time In'] = filtered_deployment_df['Time In'].astype(str)
filtered_deployment_df['Time Out'] = filtered_deployment_df['Time Out'].astype(str)

# Filter rows containing "?" in either Time In or Time Out
rows_with_question_mark = filtered_deployment_df[filtered_deployment_df['Time In'].str.contains('\?') | filtered_deployment_df['Time Out'].str.contains('\?')]

# Print the value of Offloaded Filename where there is a "?" in Time In or Time Out
if not rows_with_question_mark.empty:
    print("!!!!!WARNING CHECK!!!!!!:"
           "'?' file row", rows_with_question_mark['Offloaded Filename'].values[0],
           "May want to process file separately")
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\?'
# <>:8: SyntaxWarning: invalid escape sequence '\?'
# <>:8: SyntaxWarning: invalid escape sequence '\?'
# <>:8: SyntaxWarning: invalid escape sequence '\?'
# C:\Users\magic\AppData\Local\Temp\ipykernel_9632\2226248557.py:8: SyntaxWarning: invalid escape sequence '\?'
#   rows_with_question_mark = filtered_deployment_df[filtered_deployment_df['Time In'].str.contains('\?') | filtered_deployment_df['Time Out'].str.contains('\?')]
# C:\Users\magic\AppData\Local\Temp\ipykernel_9632\2226248557.py:8: SyntaxWarning: invalid escape sequence '\?'
#   rows_with_question_mark = filtered_deployment_df[filtered_deployment_df['Time In'].str.contains('\?') | filtered_deployment_df['Time Out'].str.contains('\?')]

# %% [markdown]
# ### Convert back to datetime
# To check for the ? in the columns, the datetime was convereted to a string. So to revert the process, the cell below does just that and checks the data type just to make sure. Formatting for date in and out was not done in the code, because it should have been formatted before importing.

# %%
#%% Convert back to datetime format
# Convert Time In and Time Out columns to datetime format
filtered_deployment_df['Time In'] = pd.to_datetime(filtered_deployment_df['Time In'], format='%H:%M:%S', errors='coerce')
filtered_deployment_df['Time Out'] = pd.to_datetime(filtered_deployment_df['Time Out'], format='%H:%M:%S', errors='coerce')

#%% Convert Date In and Date Out columns to datetime format
filtered_deployment_df['Date In'] = pd.to_datetime(filtered_deployment_df['Date In'])
filtered_deployment_df['Date Out'] = pd.to_datetime(filtered_deployment_df['Date Out'])



print(filtered_deployment_df.dtypes)  # Check the data types after conversion
# Out:
# Offloaded Filename            object
# Date In               datetime64[ns]
# Time In               datetime64[ns]
# Date Full                     object
# Date Out              datetime64[ns]
# Time Out              datetime64[ns]
# dtype: object

# %% [markdown]
# ### Combine Date and Time:
# Now that both the Date and Time are in the same format (datetime) the Date and Time the logger entered and exited deployment are combined into the same column respectively. Then if needed (commented out) the code drops the uncombined columns from the filtered_deployment_df.

# %%
# Combine the date and time columns for Date In Time In
filtered_deployment_df['Date In Time In'] = pd.to_datetime(filtered_deployment_df['Date In'].astype(str) + ' ' + filtered_deployment_df['Time In'].astype(str))

# Combine the date and time columns for Date Out Time Out
filtered_deployment_df['Date Out Time Out'] = pd.to_datetime(filtered_deployment_df['Date Out'].astype(str) + ' ' + filtered_deployment_df['Time Out'].astype(str))

# Drop the separate Date In, Time In, Date Out, and Time Out columns if needed
#filtered_deployment_df.drop(columns=['Date In', 'Time In', 'Date Out', 'Time Out'], inplace=True)

print(filtered_deployment_df)

print(filtered_deployment_df['Date In Time In'], filtered_deployment_df['Date Out Time Out'])
# Out:
#     Offloaded Filename    Date In             Time In  Date Full   Date Out  \
# 664     BT_TCBRWB_2011 2020-11-05 1900-01-01 15:27:00  1/14/2022 2021-10-22
# 665   BT_TCBKPT_2011_a 2020-10-30 1900-01-01 13:51:00   1/8/2022 2021-10-22
# 666   BT_TCBKPT_2011_b 2020-10-30 1900-01-01 13:51:00   1/8/2022 2021-10-22
# 667   BT_TCFLTC_2011_a 2020-10-30 1900-01-01 10:51:00   1/8/2022 2021-10-22
# 668   BT_TCFLTC_2011_b 2020-10-30 1900-01-01 10:51:00   1/8/2022 2021-10-22
# 689   2021-11-09 11:40:00-01:00
# 690   2021-10-19 10:45:00-01:00
# 691   2021-10-19 13:08:00-01:00
# 692   2021-11-15 10:12:00-01:00
# 693   2021-11-15 10:12:00-01:00
# 694   2021-11-11 12:11:00-01:00
# 695   2021-11-14 15:41:00-01:00
# 696   2021-11-15 15:02:00-01:00
# 697   2021-11-12 13:38:00-01:00
# 698   2021-11-12 15:29:00-01:00
# 699   2021-11-12 11:04:00-01:00
# 700   2021-11-12 10:56:00-01:00
# 701   2021-11-12 10:56:00-01:00
# 702   2021-11-16 12:03:00-01:00
# 703   2021-11-16 12:03:00-01:00
# 704   2021-11-16 11:03:00-01:00
# 705   2021-11-16 11:03:00-01:00
# 706   2021-11-13 11:37:00-01:00
# 707   2021-11-13 11:44:00-01:00
# 708   2021-11-13 11:44:00-01:00
# 709   2021-11-22 09:32:00-01:00
# 710   2021-11-14 13:47:00-01:00
# 711   2021-11-14 10:35:00-01:00
# Name: Date Out Time Out, dtype: datetime64[ns, UTC-01:00]
# C:\Users\magic\AppData\Local\Temp\ipykernel_9632\719418287.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   filtered_deployment_df['Date In Time In'] = pd.to_datetime(filtered_deployment_df['Date In'].astype(str) + ' ' + filtered_deployment_df['Time In'].astype(str))
# C:\Users\magic\AppData\Local\Temp\ipykernel_9632\719418287.py:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   filtered_deployment_df['Date Out Time Out'] = pd.to_datetime(filtered_deployment_df['Date Out'].astype(str) + ' ' + filtered_deployment_df['Time Out'].astype(str))

# %% [markdown]
# ### Problematic rows
# If the above cell block returns and error, this means that there are indiscrepencies in the data, likely the deployment log. Input the postion number in the code below that the error message states and it will tell you where the error occurs in the data.

# %%
problematic_row = filtered_deployment_df.iloc[34] #position number
print(problematic_row)
# Out:
# Offloaded Filename               BT_TCMT24_2103
# Date In                     2021-03-14 00:00:00
# Time In                     1900-01-01 10:46:00
# Date Full                             5/23/2022
# Date Out                    2021-11-12 00:00:00
# Time Out                    1900-01-01 11:04:00
# Date In Time In       2021-03-14 10:46:00-01:00
# Date Out Time Out     2021-11-12 11:04:00-01:00
# Name: 699, dtype: object

# %% [markdown]
# ### Deployment data dictionary:
# To quickly search for the deployment data without having to look through the deployment log, this cell creates a dictionary to call the related deployment data for each site code.

# %%
#%% Make a dictonary for each record contained in the filtered_deployment_df

# Create a dictionary to hold entries based on Offloaded Filename
deployment_data_dict = {}

# Iterate through DataFrame rows
for index, row in filtered_deployment_df.iterrows():
    file_info = {
        'Date In': row['Date In'], #From here
        'Time In': row['Time In'],
        'Date Full': row['Date Full'],
        'Date Out': row['Date Out'],
        'Time Out': row['Time Out'], #To here would need to be commented out if dropped in previous cell
        'Date In Time In': row['Date In Time In'],
        'Date Out Time Out': row['Date Out Time Out'],
        'Offloaded Filename': row['Offloaded Filename']
    }
    # Append file info to the dictionary using Offloaded Filename as key
    deployment_data_dict[row['Offloaded Filename']] = file_info

# Print the created dictionary
for filename, file_info in deployment_data_dict.items():
    print(f"Offloaded Filename: {filename}")
    print(f"File Info: {file_info}")
# Out:
# Offloaded Filename: BT_TCBRWB_2011
# File Info: {'Date In': Timestamp('2020-11-05 00:00:00'), 'Time In': Timestamp('1900-01-01 15:27:00'), 'Date Full': '1/14/2022', 'Date Out': Timestamp('2021-10-22 00:00:00'), 'Time Out': Timestamp('1900-01-01 12:12:00'), 'Date In Time In': Timestamp('2020-11-05 15:27:00-0100', tz='UTC-01:00'), 'Date Out Time Out': Timestamp('2021-10
00-0100', tz='UTC-01:00'), 'Date Out Time Out': Timestamp('2021-11-16 11:03:00-0100', tz='UTC-01:00'), 'Offloaded Filename': 'BT_TCCB40_2104_b'}
# Offloaded Filename: BT_TCSR30_2104_
# File Info: {'Date In': Timestamp('2021-04-08 00:00:00'), 'Time In': Timestamp('1900-01-01 09:55:00'), 'Date Full': '6/17/2022', 'Date Out': Timestamp('2021-11-13 00:00:00'), 'Time Out': Timestamp('1900-01-01 11:37:00'), 'Date In Time In': Timestamp('2021-04-08 09:55:00-0100', tz='UTC-01:00'), 'Date Out Time Out': Timestamp('2021-11-13 11:37:00-0100', tz='UTC-01:00'), 'Offloaded Filename': 'BT_TCSR30_2104_'}
# Offloaded Filename: BT_TCSR41_2104_a
# File Info: {'Date In': Timestamp('2021-04-08 00:00:00'), 'Time In': Timestamp('1900-01-01 09:55:00'), 'Date Full': '6/17/2022', 'Date Out': Timestamp('2021-11-13 00:00:00'), 'Time Out': Timestamp('1900-01-01 11:44:00'), 'Date In Time In': Timestamp('2021-04-08 09:55:00-0100', tz='UTC-01:00'), 'Date Out Time Out': Timestamp('2021-11-13 11:44:00-0100', tz='UTC-01:00'), 'Offloaded Filename': 'BT_TCSR41_2104_a'}
# Offloaded Filename: BT_TCSR41_2104_b
# File Info: {'Date In': Timestamp('2021-04-08 00:00:00'), 'Time In': Timestamp('1900-01-01 09:55:00'), 'Date Full': '6/17/2022', 'Date Out': Timestamp('2021-11-13 00:00:00'), 'Time Out': Timestamp('1900-01-01 11:44:00'), 'Date In Time In': Timestamp('2021-04-08 09:55:00-0100', tz='UTC-01:00'), 'Date Out Time Out': Timestamp('2021-11-13 11:44:00-0100', tz='UTC-01:00'), 'Offloaded Filename': 'BT_TCSR41_2104_b'}
# Offloaded Filename: BT_TCLBRH_2103
# File Info: {'Date In': Timestamp('2021-03-12 00:00:00'), 'Time In': Timestamp('1900-01-01 10:53:00'), 'Date Full': '5/21/2022', 'Date Out': Timestamp('2021-11-22 00:00:00'), 'Time Out': Timestamp('1900-01-01 09:32:00'), 'Date In Time In': Timestamp('2021-03-12 10:53:00-0100', tz='UTC-01:00'), 'Date Out Time Out': Timestamp('2021-11-22 09:32:00-0100', tz='UTC-01:00'), 'Offloaded Filename': 'BT_TCLBRH_2103'}
# Offloaded Filename: BT_TCGRPD_2103
# File Info: {'Date In': Timestamp('2021-03-13 00:00:00'), 'Time In': Timestamp('1900-01-01 13:51:00'), 'Date Full': '5/22/2022', 'Date Out': Timestamp('2021-11-14 00:00:00'), 'Time Out': Timestamp('1900-01-01 13:47:00'), 'Date In Time In': Timestamp('2021-03-13 13:51:00-0100', tz='UTC-01:00'), 'Date Out Time Out': Timestamp('2021-11-14 13:47:00-0100', tz='UTC-01:00'), 'Offloaded Filename': 'BT_TCGRPD_2103'}
# Offloaded Filename: BT_TCLBEM_2103
# File Info: {'Date In': Timestamp('2021-03-13 00:00:00'), 'Time In': Timestamp('1900-01-01 10:00:00'), 'Date Full': '5/22/2022', 'Date Out': Timestamp('2021-11-14 00:00:00'), 'Time Out': Timestamp('1900-01-01 10:35:00'), 'Date In Time In': Timestamp('2021-03-13 10:00:00-0100', tz='UTC-01:00'), 'Date Out Time Out': Timestamp('2021-11-14 10:35:00-0100', tz='UTC-01:00'), 'Offloaded Filename': 'BT_TCLBEM_2103'}

# %% [markdown]
# ### Example deployment metadata call using the deployment_data_dict dictionary:

# %%
# Example deployment data call
#deployment_data_dict["BT_TCSR41_2210_a"]

# %% [markdown]
# ### Match the Date Times data type in deployment data dictionary to the times data type in df_files ###
# This loop iterates through each file in the deployment data dictionary and converts the Date Times into a stringtime format.

# %%
#%% Change Date Times in deployment_data_dict to match the times in df_files

# Iterate through deployment_data_dict
for filename, file_info in deployment_data_dict.items():
    # Convert 'Date In Time Out' and 'Date Out Time Out' to the specified format
    file_info['Date In Time In'] = file_info['Date In Time In'].strftime('%m/%d/%y %H:%M:%S')
    file_info['Date Out Time Out'] = file_info['Date Out Time Out'].strftime('%m/%d/%y %H:%M:%S')

# Now the values for 'Date In Time Out' and 'Date Out Time Out' are in the specified time format

# %% [markdown]
# ## Plot pre-trimmed files
# This plots the pre-trimmed version of the files

# %%
# Loop through df_files and plot graphs for each DataFrame
for site_code, site_data in df_files.items():
    for file_number, file_data in site_data.items():
        for file_identifier, file_info in file_data.items():
            # Get the DataFrame
            df = file_info['DataFrame']
            
            # Convert the 'Date Time, GMT-04:00' column to datetime format
            df['Date Time, GMT-04:00'] = pd.to_datetime(df['Date Time, GMT-04:00'])

            # Plot the temperature over time
            plt.figure(figsize=(12, 6))
            plt.plot(df.index, df['Temp, °C'], color='blue', marker='o', linestyle='-')
            plt.title('Temperature Over Time')
            plt.xlabel('Date Time')
            plt.ylabel('Temp, °C')  # Modified label
            plt.grid(True)
            plt.xticks(rotation=45)
            plt.tight_layout()
            plt.show()
# Out:
# C:\Users\magic\AppData\Local\Temp\ipykernel_9632\281288637.py:9: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date Time, GMT-04:00'] = pd.to_datetime(df['Date Time, GMT-04:00'])
# C:\Users\magic\AppData\Local\Temp\ipykernel_9632\281288637.py:9: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date Time, GMT-04:00'] = pd.to_datetime(df['Date Time, GMT-04:00'])
# C:\Users\magic\AppData\Local\Temp\ipykernel_9632\281288637.py:9: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date Time, GMT-04:00'] = pd.to_datetime(df['Date Time, GMT-04:00'])
# C:\Users\magic\AppData\Local\Temp\ipykernel_9632\281288637.py:9: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date Time, GMT-04:00'] = pd.to_datetime(df['Date Time, GMT-04:00'])
# C:\Users\magic\AppData\Local\Temp\ipykernel_9632\281288637.py:9: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date Time, GMT-04:00'] = pd.to_datetime(df['Date Time, GMT-04:00'])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 9
#       6 df = file_info['DataFrame']
#       8 # Convert the 'Date Time, GMT-04:00' column to datetime format
# ----> 9 df['Date Time, GMT-04:00'] = pd.to_datetime(df['Date Time, GMT-04:00'])
#      11 # Plot the temperature over time
#      12 plt.figure(figsize=(12, 6))
#
# File c:\Users\magic\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\tools\datetimes.py:1112, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1110         result = arg.map(cache_array)
#    1111     else:
# -> 1112         values = convert_listlike(arg._values, format)
#    1113         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1114 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File c:\Users\magic\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\tools\datetimes.py:490, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     487 if format is not None and format != "mixed":
#     488     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
# --> 490 result, tz_parsed = objects_to_datetime64ns(
#     491     arg,
#     492     dayfirst=dayfirst,
#     493     yearfirst=yearfirst,
#     494     utc=utc,
#     495     errors=errors,
#     496     allow_object=True,
#     497 )
#     499 if tz_parsed is not None:
#     500     # We can take a shortcut since the datetime64 numpy array
#     501     # is in UTC
#     502     dta = DatetimeArray(result, dtype=tz_to_dtype(tz_parsed))
#
# File c:\Users\magic\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\arrays\datetimes.py:2346, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, allow_object)
#    2343 # if str-dtype, convert
#    2344 data = np.array(data, copy=False, dtype=np.object_)
# -> 2346 result, tz_parsed = tslib.array_to_datetime(
#    2347     data,
#    2348     errors=errors,
#    2349     utc=utc,
#    2350     dayfirst=dayfirst,
#    2351     yearfirst=yearfirst,
#    2352 )
#    2354 if tz_parsed is not None:
#    2355     # We can take a shortcut since the datetime64 numpy array
#    2356     #  is in UTC
#    2357     # Return i8 values to denote unix timestamps
#    2358     return result.view("i8"), tz_parsed
#
# File tslib.pyx:403, in pandas._libs.tslib.array_to_datetime()
#
# File tslib.pyx:517, in pandas._libs.tslib.array_to_datetime()
#
# File conversion.pyx:546, in pandas._libs.tslibs.conversion.convert_str_to_tsobject()
#
# File parsing.pyx:331, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File parsing.pyx:654, in pandas._libs.tslibs.parsing.dateutil_parse()
#
# File c:\Users\magic\AppData\Local\Programs\Python\Python312\Lib\site-packages\dateutil\parser\_parser.py:724, in parser._parse(self, timestr, dayfirst, yearfirst, fuzzy, fuzzy_with_tokens)
#     721 skipped_idxs = []
#     723 # year/month/day list
# --> 724 ymd = _ymd()
#     726 len_l = len(l)
#     727 i = 0
#
# KeyboardInterrupt:

# %% [markdown]
# ### <b>Trim the data based on Date Time:
# Trimming the data occurs in two steps, first is to trim the data based on the deployment log, then trim the data to account for human error. The cell below checks if the newly combined Date and Time values are a string and then formats it to a datetime object with the structure of m/d/y and h:m:s.

# %%
#%% Trim Data Based on Date Time
# The data is being trimmed to the closest related start and endpoint 

# Convert timestamps to datetime objects in deployment_data_dict
for filename, file_info in deployment_data_dict.items():
    # Check if the values are already strings
    if isinstance(file_info['Date In Time In'], str):
        file_info['Date In Time In'] = datetime.strptime(file_info['Date In Time In'], '%m/%d/%y %H:%M:%S')
    if isinstance(file_info['Date Out Time Out'], str):
        file_info['Date Out Time Out'] = datetime.strptime(file_info['Date Out Time Out'], '%m/%d/%y %H:%M:%S')

# %% [markdown]
# ### Trim part 1: deployment log
# This cell trims the data based on the start and end times specified in the deployment log to the nearest point in the data.

# %%
# Trim the data in each DataFrame based on the specified time range
for site_code, site_data in df_files.items():
    for file_number, file_data in site_data.items():
        for file_identifier, file_info in file_data.items():
            df = file_info['DataFrame']
            date_column = 'Date Time, GMT-04:00'  # Assuming this is the column containing timestamps
            
            # Convert the date column to datetime objects, specifying the format
           # df[date_column] = pd.to_datetime(df[date_column], format='%m/%d/%Y %H:%M')
            df[date_column] = pd.to_datetime(df[date_column], format='%m/%d/%y %H:%M:%S')
            
            # Filter the DataFrame based on the specified time range
            df = df[(df[date_column] >= deployment_data_dict[file_info['File Name']]['Date In Time In']) &
                    (df[date_column] <= deployment_data_dict[file_info['File Name']]['Date Out Time Out'])]
            
            # Update the DataFrame in df_files
            df_files[site_code][file_number][file_identifier]['DataFrame'] = df

# %% [markdown]
# ### Trim part 2: account for human error
# To remove the possibility of human error from deployment and retreival of the loggers, the loop iterates through the data frames and trims the first and last hour of the data. This section can be altered in the "trimmed_df = df.iloc[4:-5]" section based on outputs of graphing section of the code.

# %%
#%% Trim data down on both ends by an hour THIS SECTION CAN BE COMMENTED OUT IF FURTHER TRIMMING IS NOT REQUIRED.
# This is to eliminate any data errors from the removal and retrevial from the water.
# In terms of data processing it may be better to eliminate human error and just inerpolate these points
# When connecting the data to previous data. 

# Loop through each site code, file number, and file identifier in df_files
for site_code, site_data in df_files.items():
    for file_number, file_data in site_data.items():
        for file_identifier, file_info in file_data.items():
            # Get the DataFrame for the current file
            df = file_info['DataFrame']
            
            # Reduce the number of start points 4 and end points by 5 on each end of the DataFrame
            trimmed_df = df.iloc[4:-5]
            
            # Update the DataFrame in df_files
            df_files[site_code][file_number][file_identifier]['DataFrame'] = trimmed_df

# %% [markdown]
# ### Checking the lengths:
# This loop makes sure that the number of rows for each site code are the same to ensure that they can be merged and then averaged. If not then those files are named c and d and are considered offset files. This would be the point to check for differences in time interval between the data pairs. If time interval is different then place them in a new dictionary and merge times. Confirm that "b" file no longer exists if it does remove it.

# %%
#%% Checks to see if the "a" and "b" files and the "c" and "d" files have the same number of data points

# Iterate through each site code
for site_code, file_numbers in df_files.items():
    # Iterate through each file number
    for file_number, identifiers in file_numbers.items():
        # Check if there are multiple file identifiers for the file number
        if len(identifiers) > 1:
            # Get the DataFrames associated with the current site code, file number, and identifiers
            data_frames = [info['DataFrame'] for identifier, info in identifiers.items()]
            
            # Get the number of rows for each DataFrame
            num_rows = [df.shape[0] for df in data_frames]
            
            # Check if files associated with the file number have different numbers of data points
            if len(set(num_rows)) != 1:
                print(f"Site code: {site_code}, File number: {file_number} have files with different numbers of data points.")
            else:
                print(f"Site code: {site_code}, File number: {file_number} have files with the same number of data points: {num_rows[0]}.")
# Out:
# Site code: TCBKIX, File number: 2103 have files with the same number of data points: 23510.
# Site code: TCBKPT, File number: 2011 have files with the same number of data points: 34261.
# Site code: TCCB08, File number: 2104 have files with the same number of data points: 21497.
# Site code: TCCB40, File number: 2104 have files with the same number of data points: 21497.
# Site code: TCCORK, File number: 2011 have files with the same number of data points: 29660.
# Site code: TCFLTC, File number: 2011 have files with the same number of data points: 34259.
# Site code: TCGMKT, File number: 2011 have files with the same number of data points: 34255.
# Site code: TCHB40, File number: 2012 have files with the same number of data points: 34922.
# Site code: TCMT40, File number: 2103 have files with the same number of data points: 23320.
# Site code: TCSC35, File number: 2011 have files with the same number of data points: 34250.
# Site code: TCSCAP, File number: 2011 have files with the same number of data points: 31764.
# Site code: TCSHCS, File number: 2011 have files with the same number of data points: 31842.
# Site code: TCSR41, File number: 2104 have files with the same number of data points: 21022.

# %%
#calls a dataframe
#print(df_files['TCBKIX']['2210']['a'])

# %% [markdown]
# ### Calculations check:
# To merge the duplicate temperature columns, the difference between each temperature must be checked before they can be averaged. After checking if there is an a and b file for each site code, the code then takes the absoulte value of the difference between them.

# %%
#%% Check to see if there is a .2 degrees difference then average the two columns and record the site codes where this occured 
# Also take the average between the two temperature columns if the difference is less than or equal to .2 degrees.
# Use the new average temperature column as the temperature column 
# Iterate through each site code
for site_code, file_numbers in df_files.items():
    # Iterate through each file number
    for file_number, identifiers in file_numbers.items():
        # Check if there are both 'a' and 'b' files for the current site code and file number
        if 'a' in identifiers and 'b' in identifiers:
            # Get the 'a' and 'b' dataframes
            df_a = identifiers['a']['DataFrame']
            df_b = identifiers['b']['DataFrame']
            
            # Check if the temperature columns exist in both dataframes
            if 'Temp, °C' in df_a.columns and 'Temp, °C' in df_b.columns:
                # Calculate the temperature difference
                df_a['Temperature_Difference'] = abs(df_a['Temp, °C'] - df_b['Temp, °C'])
            else:
                print(f"Temperature columns not found for Site: {site_code}, File Number: {file_number}")
        else:
            print(f"Only one file for Site: {site_code}, File Number: {file_number}, so averaging could not occur")
# Out:
# Only one file for Site: TCBKIT, File Number: 2011, so averaging could not occur
# Only one file for Site: TCBOTB, File Number: 2011, so averaging could not occur
# Only one file for Site: TCBRWB, File Number: 2011, so averaging could not occur
# Only one file for Site: TCCLGE, File Number: 2012, so averaging could not occur
# Only one file for Site: TCCORB, File Number: 2012, so averaging could not occur
# Only one file for Site: TCCSTL, File Number: 2104, so averaging could not occur
# Only one file for Site: TCEAGR, File Number: 2104, so averaging could not occur
# Only one file for Site: TCFSHB, File Number: 2012, so averaging could not occur
# Only one file for Site: TCGRPD, File Number: 2103, so averaging could not occur
# Only one file for Site: TCJCKB, File Number: 2104, so averaging could not occur
# Only one file for Site: TCKNGC, File Number: 2103, so averaging could not occur
# Only one file for Site: TCLBEM, File Number: 2103, so averaging could not occur
# Only one file for Site: TCLBRH, File Number: 2103, so averaging could not occur
# Only one file for Site: TCLSTJ, File Number: 2011, so averaging could not occur
# Only one file for Site: TCMAGB, File Number: 2011, so averaging could not occur
# Only one file for Site: TCMERI, File Number: 2012, so averaging could not occur
# Only one file for Site: TCMT24, File Number: 2103, so averaging could not occur
# Only one file for Site: TCSAVA, File Number: 2011, so averaging could not occur
# Only one file for Site: TCSPTH, File Number: 2103, so averaging could not occur
# Only one file for Site: TCSR30, File Number: 2104, so averaging could not occur
# Only one file for Site: TCSWAT, File Number: 2012, so averaging could not occur

# %% [markdown]
# ### Merge the offset files:
# This loop checks if the c and d identifiers exist within the files. If they exist, then the code gets the data frame for each and merges them based on the Date Time column. For the instances where the merge occured, a new identifier is added to the df_files dictionary called 'merged'. <u>This code needs to be further tested<u>

# %%
#%% If dataframes are 'c' and 'd' then merge the dataframes on the 'Date Time, GMT-04:00'
# Iterate through each site code
for site_code, file_numbers in df_files.items():
    # Iterate through each file number
    for file_number, identifiers in file_numbers.items():
        # Check if 'c' and 'd' identifiers exist for the current site code and file number
        if 'c' in identifiers and 'd' in identifiers:
            # Get the 'c' and 'd' DataFrames
            df_c = identifiers['c']['DataFrame']
            df_d = identifiers['d']['DataFrame']
            
            # Check if the 'Date Time, GMT-04:00' column exists in both DataFrames
            if 'Date Time, GMT-04:00' in df_c.columns and 'Date Time, GMT-04:00' in df_d.columns:
                # Merge the DataFrames on the 'Date Time, GMT-04:00' column
                merged_df = pd.merge(df_c, df_d, on='Date Time, GMT-04:00', how='outer', suffixes=('_c', '_d'))
                
                # Add the merged DataFrame to df_files under a new identifier 'merged'
                df_files[site_code][file_number]['merged'] = {'DataFrame': merged_df, 'File Name': 'merged'}
                
                # Optionally, you can drop the 'c' and 'd' DataFrames if needed
                # del df_files[site_code][file_number]['c']
                # del df_files[site_code][file_number]['d']
            else:
                print(f"'Date Time, GMT-04:00' column not found in 'c' or 'd' DataFrame for Site: {site_code}, File Number: {file_number}")
        else:
            print(f"Only one file for Site: {site_code}, File Number: {file_number}, so merging could not occur")
# Out:
# Only one file for Site: TCBKIT, File Number: 2011, so merging could not occur
# Only one file for Site: TCBKIX, File Number: 2103, so merging could not occur
# Only one file for Site: TCBKPT, File Number: 2011, so merging could not occur
# Only one file for Site: TCBOTB, File Number: 2011, so merging could not occur
# Only one file for Site: TCBRWB, File Number: 2011, so merging could not occur
# Only one file for Site: TCCB08, File Number: 2104, so merging could not occur
# Only one file for Site: TCCB40, File Number: 2104, so merging could not occur
# Only one file for Site: TCCLGE, File Number: 2012, so merging could not occur
# Only one file for Site: TCCORB, File Number: 2012, so merging could not occur
# Only one file for Site: TCCORK, File Number: 2011, so merging could not occur
# Only one file for Site: TCCSTL, File Number: 2104, so merging could not occur
# Only one file for Site: TCEAGR, File Number: 2104, so merging could not occur
# Only one file for Site: TCFLTC, File Number: 2011, so merging could not occur
# Only one file for Site: TCFSHB, File Number: 2012, so merging could not occur
# Only one file for Site: TCGMKT, File Number: 2011, so merging could not occur
# Only one file for Site: TCGRPD, File Number: 2103, so merging could not occur
# Only one file for Site: TCHB40, File Number: 2012, so merging could not occur
# Only one file for Site: TCJCKB, File Number: 2104, so merging could not occur
# Only one file for Site: TCKNGC, File Number: 2103, so merging could not occur
# Only one file for Site: TCLBEM, File Number: 2103, so merging could not occur
# Only one file for Site: TCLBRH, File Number: 2103, so merging could not occur
# Only one file for Site: TCLSTJ, File Number: 2011, so merging could not occur
# Only one file for Site: TCMAGB, File Number: 2011, so merging could not occur
# Only one file for Site: TCMERI, File Number: 2012, so merging could not occur
# Only one file for Site: TCMT24, File Number: 2103, so merging could not occur
# Only one file for Site: TCMT40, File Number: 2103, so merging could not occur
# Only one file for Site: TCSAVA, File Number: 2011, so merging could not occur
# Only one file for Site: TCSC35, File Number: 2011, so merging could not occur
# Only one file for Site: TCSCAP, File Number: 2011, so merging could not occur
# Only one file for Site: TCSHCS, File Number: 2011, so merging could not occur
# Only one file for Site: TCSPTH, File Number: 2103, so merging could not occur
# Only one file for Site: TCSR30, File Number: 2104, so merging could not occur
# Only one file for Site: TCSR41, File Number: 2104, so merging could not occur
# Only one file for Site: TCSWAT, File Number: 2012, so merging could not occur

# %% [markdown]
# ### Calculations:
# The files whose temperatures had a greater difference than 0.2 needs to be labeled as calculations for futher manual investigation. An empty dictionary named calculations is created then after checking that the files with the temperature difference column exists, they are stored in the dictionary. The end of the code then prints the names of these files that were labeled as calculations.

# %%
#%%
# Create an empty dictionary to store calculations
calculations = {}

# Iterate through each site code
for site_code, file_numbers in df_files.items():
    # Iterate through each file number
    for file_number, identifiers in file_numbers.items():
        # Check if the 'a' identifier exists for the current site code and file number
        if 'a' in identifiers:
            # Get the 'a' dataframe
            df_a = identifiers['a']['DataFrame']
            
            # Check if the 'Temperature_Difference' column exists in the dataframe
            if 'Temperature_Difference' in df_a.columns:
                # Filter rows where 'Temperature_Difference' is above 0.2
                above_threshold = df_a[df_a['Temperature_Difference'] > 0.2]
                
                # Check if there are any rows above the threshold
                if not above_threshold.empty:
                    # Get the file name associated with the 'a' dataframe
                    file_name = identifiers['a']['File Name']
                    
                    # Store site code, file number, and file name in the calculations dictionary
                    calculations[(site_code, file_number)] = file_name
            #else:
            #    print(f"Temperature_Difference column not found for Site: {site_code}, File Number: {file_number}")
print()
print('These are the files that need to be labeled as calculations:')
for key, value in calculations.items():
    print(key, value)
# Out:
# These are the files that need to be labeled as calculations:
# ('TCMT40', '2103') BT_TCMT40_2103_a

# %% [markdown]
# ### Copy df_files
# Used for calculations comparisons

# %%
calc_df = df_files

# %% [markdown]
# ### Create a new dictionary for calculation comparisons
# This cell makes a new nested dictionary to extract the dataframes from df_files marked for calculations so they can be manipulated with out disturbing the original data structure.

# %%
# Initialize an empty dictionary to store DataFrames corresponding to calculations
calc_df_files = {}

# Iterate through each key-value pair in the calculations dictionary
for (site_code, file_number), file_name in calculations.items():
    # Check if the site code exists in calc_df dictionary
    if site_code in calc_df:
        # Check if the file number exists for the site code
        if file_number in calc_df[site_code]:
            for identifier in ['a', 'b']:  # Iterate through both 'a' and 'b' identifiers
                # Extract the DataFrame corresponding to the identifier from df_files dictionary
                df = calc_df[site_code][file_number].get(identifier)
                if df is not None:
                    # Create a nested dictionary entry in calc_df_files
                    if site_code not in calc_df_files:
                        calc_df_files[site_code] = {}
                    if file_number not in calc_df_files[site_code]:
                        calc_df_files[site_code][file_number] = {}
                    calc_df_files[site_code][file_number][identifier] = df
        else:
            print(f"File number {file_number} not found for site code {site_code} in calc_df.")
    else:
        print(f"Site code {site_code} not found in calc_df.")

# Now, calc_df_files will contain the DataFrames corresponding to the files listed in the calculations dictionary, including both 'a' and 'b' identifiers.

# %% [markdown]
# ### Create comparison columns for calculations
# This cell iterates through the dataframes in calc_df_files, and adds the temperature column from the _b dataframe to the _a dataframe. These columns are then renamed as Temp A and Temp B.

# %%
# Iterate through each site code
for site_code, file_numbers in calc_df_files.items():
    # Iterate through each file number
    for file_number, identifiers in file_numbers.items():
        if 'a' in identifiers:
            # Get the dataframe calc_a
            calc_a = identifiers['a']['DataFrame']
            calc_b = identifiers['b']['DataFrame']
            
            # Add the temp column from b to a and rename both
            calc_a["Temp A"] = calc_a.loc[:, "Temp, °C"]
            calc_a["Temp B"] = calc_b.loc[:, "Temp, °C"]
            
            #Add the average column
            calc_a["Average_temp"] = (calc_a['Temp A'] + calc_a['Temp B'])/2

            #Add a boolean flag column
            calc_a['Flag'] = calc_a["Temperature_Difference"] > 0.2
            

            # Print calc_a
            print(f"DataFrame for Site Code: {site_code}, File Number: {file_number} (calc_a)")
            print(calc_a)
            print("\n")
# Out:
# DataFrame for Site Code: TCMT40, File Number: 2103 (calc_a)
#            # Date Time, GMT-04:00  Temp, °C Coupler Detached Coupler Attached  \
# 1067    1068  2021-03-14 11:45:00    26.598              NaN              NaN
# 1068    1069  2021-03-14 12:00:00    26.598              NaN              NaN
# 1069    1070  2021-03-14 12:15:00    26.598              NaN              NaN
# 1070    1071  2021-03-14 12:30:00    26.598              NaN              NaN
# 1071    1072  2021-03-14 12:45:00    26.598              NaN              NaN
# ...      ...                  ...       ...              ...              ...
# 24382  24383  2021-11-12 08:30:00    28.791              NaN              NaN
# 24383  24384  2021-11-12 08:45:00    28.816              NaN              NaN
# 24384  24385  2021-11-12 09:00:00    28.891              NaN              NaN
# 24385  24386  2021-11-12 09:15:00    28.816              NaN              NaN
# 24386  24387  2021-11-12 09:30:00    28.816              NaN              NaN
#
#       Host Connected Stopped End Of File  Temperature_Difference  Temp A  \
# 1067             NaN     NaN         NaN                   0.000  26.598
# 1068             NaN     NaN         NaN                   0.000  26.598
# 1069             NaN     NaN         NaN                   0.000  26.598
# 1070             NaN     NaN         NaN                   0.000  26.598
# 1071             NaN     NaN         NaN                   0.000  26.598
# ...              ...     ...         ...                     ...     ...
# 24382            NaN     NaN         NaN                   0.000  28.791
# 24383            NaN     NaN         NaN                   0.025  28.816
# 24384            NaN     NaN         NaN                   0.025  28.891
# 24385            NaN     NaN         NaN                   0.025  28.816
# 24386            NaN     NaN         NaN                   0.025  28.816
#
#        Temp B  Average_temp   Flag
# 1067   26.598       26.5980  False
# 1068   26.598       26.5980  False
# 1069   26.598       26.5980  False
# 1070   26.598       26.5980  False
# 1071   26.598       26.5980  False
# ...       ...           ...    ...
# 24382  28.791       28.7910  False
# 24383  28.791       28.8035  False
# 24384  28.866       28.8785  False
# 24385  28.791       28.8035  False
# 24386  28.791       28.8035  False
#
# [23320 rows x 13 columns]

# %% [markdown]
# ### Report number of "true" flags for each calculations file
# Shows the number of cells where the difference in temperature is greater than 0.2

# %%
# Iterate through each site code
for site_code, file_numbers in calc_df_files.items():
    # Iterate through each file number
    for file_number, identifiers in file_numbers.items():
        if 'a' in identifiers:
            # Get the dataframe calc_a
            calc_a = identifiers['a']['DataFrame']
            
            # Count the number of 'True' values in the filtered DataFrame
            true_count = calc_a['Flag'].astype(str).value_counts().get('True',0)
            print(f"{site_code} {file_number}, Number of 'True' values flagged: {true_count}")
# Out:
# TCMT40 2103, Number of 'True' values flagged: 1

# %% [markdown]
# ### Offload calculation comparisons
# This cell will offload the files marked as calculations. Each file will have the number, date time, and two temperature columns for comparison and the difference between them. These files will then be uploaded to the calculations folder on the google drive for the year specified.
#
# <l><u>Make sure to update the working directory!

# %%
# Define the output folder where you want to save the extracted files
output_folder = r"C:\UVI\QAQC stuff\Temp_TCRMP_2023_Output"

# Define the calculations folder within the output folder
calculations_folder = os.path.join(output_folder, "Provisional Duplicates")

# Create the calculations folder if it doesn't exist
if not os.path.exists(calculations_folder):
    os.makedirs(calculations_folder)

# Iterate through each site code
for site_code, file_numbers in calc_df_files.items():
    # Iterate through each file number
    for file_number, identifiers in file_numbers.items():
        # Check if 'a' identifier exists
        if 'a' in identifiers:
            # Get the dataframe calc_a
            calc_a = identifiers['a']['DataFrame']
            
            # Get the year and month of the first and last data points
            first_data_point = calc_a['Date Time, GMT-04:00'].iloc[0]
            last_data_point = calc_a['Date Time, GMT-04:00'].iloc[-1]
            year_month_first = first_data_point.strftime("%y%m")  # Using last two digits of the year
            year_month_last = last_data_point.strftime("%y%m")    # Using last two digits of the year
            
            # Construct the base file name
            base_file_name = f"BT_{site_code}_{year_month_first}_{year_month_last}"
            
            # Construct the output file name for 'a' file
            output_file_name = f"PD_{base_file_name}.csv"
            output_file_path = os.path.join(calculations_folder, output_file_name)
            
            # Drop unnecessary columns from calc_a
            calc_a = calc_a[['#', 'Date Time, GMT-04:00', 'Temp A', 'Temp B', 'Temperature_Difference','Average_temp','Flag']]
            
            # Save the 'a' DataFrame to CSV
            calc_a.to_csv(output_file_path, index=False)
            
            print(f"File saved: Site: {site_code}, File Number: {file_number}, Path: {output_file_path}")
        else:
            print(f"No 'a' version found for Site: {site_code}, File Number: {file_number}")
# Out:
# File saved: Site: TCMT40, File Number: 2103, Path: C:\UVI\QAQC stuff\Temp_TCRMP_2023_Output\Provisional Duplicates\PD_BT_TCMT40_2103_2111.csv

# %% [markdown]
# ### Averaging:
# If the difference is 0.2 or less, the old temperature columns are dropped and replaced by the averaged one. If the difference is greater than 0.2 the columns are not averaged and are left blank to be identified in a later cell.

# %%
#%% Check to see if there is a .2 degrees difference then average the two columns and record the site codes where this occured 
# Also take the average between the two temperature columns if the difference is less than or equal to .2 degrees.
# Use the new average temperature column as the temperature column 
# Iterate through each site code
for site_code, file_numbers in df_files.items():
    # Iterate through each file number
    for file_number, identifiers in file_numbers.items():
        # Check if there are both 'a' and 'b' files for the current site code and file number
        if 'a' in identifiers and 'b' in identifiers:
            # Get the 'a' and 'b' dataframes
            df_a = identifiers['a']['DataFrame']
            df_b = identifiers['b']['DataFrame']
            
            # Check if the temperature columns exist in both dataframes
            if 'Temp, °C' in df_a.columns and 'Temp, °C' in df_b.columns:
                # Calculate the average temperature between the two temperature columns of "a" and "b" if the temperature difference is .2 or below
                df_a['Average_Temperature'] = df_a.apply(
                    lambda row: (row['Temp, °C'] + df_b.loc[row.name,'Temp, °C']) / 2 if row['Temperature_Difference'] <= 0.2 else None,
                    axis=1
                )
                # Drop the old 'Temp, °C' column to replace with new average column
                df_a.drop(columns=['Temp, °C'], inplace=True)
                
                # Rename the Average Temperature column
                df_a.rename(columns={'Average_Temperature': 'Temp, °C'}, inplace=True)
                
            else:
                print(f"Temperature columns not found for Site: {site_code}, File Number: {file_number}")
        else:
            print(f"Only one file for Site: {site_code}, File Number: {file_number}, so averaging could not occur")
# Out:
# Only one file for Site: TCBKIT, File Number: 2011, so averaging could not occur
# Only one file for Site: TCBOTB, File Number: 2011, so averaging could not occur
# Only one file for Site: TCBRWB, File Number: 2011, so averaging could not occur
# Only one file for Site: TCCLGE, File Number: 2012, so averaging could not occur
# Only one file for Site: TCCORB, File Number: 2012, so averaging could not occur
# Only one file for Site: TCCSTL, File Number: 2104, so averaging could not occur
# Only one file for Site: TCEAGR, File Number: 2104, so averaging could not occur
# Only one file for Site: TCFSHB, File Number: 2012, so averaging could not occur
# Only one file for Site: TCGRPD, File Number: 2103, so averaging could not occur
# Only one file for Site: TCJCKB, File Number: 2104, so averaging could not occur
# Only one file for Site: TCKNGC, File Number: 2103, so averaging could not occur
# Only one file for Site: TCLBEM, File Number: 2103, so averaging could not occur
# Only one file for Site: TCLBRH, File Number: 2103, so averaging could not occur
# Only one file for Site: TCLSTJ, File Number: 2011, so averaging could not occur
# Only one file for Site: TCMAGB, File Number: 2011, so averaging could not occur
# Only one file for Site: TCMERI, File Number: 2012, so averaging could not occur
# Only one file for Site: TCMT24, File Number: 2103, so averaging could not occur
# Only one file for Site: TCSAVA, File Number: 2011, so averaging could not occur
# Only one file for Site: TCSPTH, File Number: 2103, so averaging could not occur
# Only one file for Site: TCSR30, File Number: 2104, so averaging could not occur
# Only one file for Site: TCSWAT, File Number: 2012, so averaging could not occur

# %% [markdown]
# ### Show NaNs for calculations:
# During the averaging for the temperature difference, points where the temperature difference was above 0.2 were not averaged and left empty as NaN. The code below prints the number of points where the temperature difference was above 0.2 degrees for calculations file.

# %%
#%% Print the number of NaNs to show the number of points that are above a .2 temperature difference
# The number of NaNs represents the number of points where the temperature difference was above .2

# Iterate through each file in calculations
for (site_code, file_number), file_name in calculations.items():
    # Get the 'a' dataframe associated with the file
    df_a = df_files[site_code][file_number]['a']['DataFrame']

    # Check if the dataframe and the 'Temp, °C' column exist
    if df_a is not None and 'Temp, °C' in df_a.columns:
        # Count the number of NaNs in the 'Temp, °C column
        nan_count = df_a['Temp, °C'].isna().sum()

        # Print the file details and the NaN count
        print(f"For file {file_name}") 
        print(f"{nan_count} is the number of points where the temperature difference was above .2°C")
        print()
# Out:
# For file BT_TCMT40_2103_a
# 1 is the number of points where the temperature difference was above .2°C

# %% [markdown]
# ### Drop unesscessary columns:
# In the SOP, every .csv file must only contain the '#'. 'Date Time, GMT-04:00', and 'Temp, °C' columns and so the code loops through each file identifier so that each file will drop all other columns.

# %%
#%% Drop columns
# Iterate through each site code
for site_code, file_numbers in df_files.items():
    # Iterate through each file number
    for file_number, identifiers in file_numbers.items():
        # Check if there are both 'a' and 'b' files for the current site code and file number
        if 'a' in identifiers:
            # Get the 'a' dataframe
            df_a = identifiers['a']['DataFrame']
            
            # Drop all columns except '#' 'Date Time, GMT-04:00' and 'Temp, °C'
            columns_to_keep = ['#', 'Date Time, GMT-04:00', 'Temp, °C']
            df_a = df_a[columns_to_keep]
            #df_a = df_a.rename(columns={'#': 'number','Date Time, GMT-04:00': 'Date Time GMT-04:00','Temp, °C': 'Temp C'})
            
            # Update the dataframe in df_files
            df_files[site_code][file_number]['a']['DataFrame'] = df_a

            if 'b' in identifiers:
                # Get the 'b' dataframe
                df_b = identifiers['b']['DataFrame']

                # Drop all columns except '#', 'Date Time, GMT-04:00' and 'Temp, °C'
                df_b = df_b[columns_to_keep]

                # Update the dataframe in df_files
                df_files[site_code][file_number]['b']['DataFrame'] = df_b

                if 'c' in identifiers:
                    # Get the 'c' dataframe
                    df_c = identifiers['c']['DataFrame']

                    # Drop all columns except '#', 'Date Time, GMT-04:00' and 'Temp, °C'
                    df_c = df_c[columns_to_keep]

                    # Update the dataframe in df_files
                    df_files[site_code][file_number]['c']['DataFrame'] = df_c
                    
                    if 'd' in identifiers:
                        # Get the 'd' dataframe
                        df_d = identifiers['d']['DataFrame']

                        # Drop all columns except '#', 'Date Time, GMT-04:00' and 'Temp, °C'
                        df_d = df_d[columns_to_keep]

                        # Update the dataframe in df_files
                        df_files[site_code][file_number]['d']['DataFrame'] = df_d

# %% [markdown]
# ### <b>Plotting graphs:
# To visualize the change in temperature variability, the codes below generate graphs for the different sites.

# %% [markdown]
# ### Individual plotting:
# Uncommenting this code will generate a graph for a specific site if desired

# %%
#%% Individual plots

# # Get the DataFrame
df = df_files['TCCLGE']['2012']['a']['DataFrame']

# # Convert the 'Date Time, GMT-04:00' column to datetime format
df['Date Time, GMT-04:00'] = pd.to_datetime(df['Date Time, GMT-04:00'])


# # Plot the temperature over time
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['Temp, °C'], color='blue', marker='o', linestyle='-')
plt.title('Temperature Over Time')
plt.xlabel('Date Time')
plt.ylabel('Temp, °C')  # Modified label
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Plotting Loop without displaying months:
# If faster graph generation is desired, uncomment the cell below to generate the graphs for each site without displaying the months. This code is good for getting an idea of the shape for each file.

# %%
#%% Loop all plots without altering time to display as months -- Runs Faster

# # Loop through df_files and plot graphs for each DataFrame
# for site_code, site_data in df_files.items():
#     for file_number, file_data in site_data.items():
#         for file_identifier, file_info in file_data.items():
#             # Get the DataFrame
#             df = file_info['DataFrame']

#             # Convert the 'Date Time, GMT-04:00' column to datetime format
#             #df['Date Time, GMT-04:00'] = pd.to_datetime(df['Date Time, GMT-04:00'])
            
#             # This was changed to deal with a error caused by modify a slice of a dataframe
#             # This iloc explicitly sets values in the dataframe 
#             df.loc[:, 'Date Time, GMT-04:00'] = pd.to_datetime(df['Date Time, GMT-04:00'])

#             # Plot the temperature over time
#             plt.figure(figsize=(12, 6))
#             plt.plot(df.index, df['Temp, °C'], color='blue', marker='o', linestyle='-')
#             plt.title(f'Temperature Over Time - Site: {site_code}, File Number: {file_number}, Identifier: {file_identifier}')
#             plt.xlabel('Date Time')
#             plt.ylabel('Temp, °C')
#             plt.grid(True)
#             plt.xticks(rotation=45)
#             plt.tight_layout()
#             plt.show()

# %% [markdown]
# ### Loop for plotting the sites:
# This cell will generate graphs for the temperature change over the deployments for every site including months along the x axis.

# %%
#%% Loop through df_files and plot graphs for each DataFrame where time is displayed as months

# Loop through df_files and plot graphs for each DataFrame
for site_code, site_data in df_files.items():
    for file_number, file_data in site_data.items():
        for file_identifier, file_info in file_data.items():
            # Get the DataFrame
            df = file_info['DataFrame']

            # Convert the 'Date Time, GMT-04:00' column to datetime format
            df.loc[:, 'Date Time, GMT-04:00'] = pd.to_datetime(df['Date Time, GMT-04:00'])

            # Plot the temperature over time
            plt.figure(figsize=(12, 6))
            plt.plot(df.index, df['Temp, °C'], color='blue', marker='o', linestyle='-')
            plt.title(f'Temperature Over Time - Site: {site_code}, File Number: {file_number}, Identifier: {file_identifier}')
            plt.xlabel('Date Time')
            plt.ylabel('Temp, °C')
            plt.grid(True)
            
            # Set x-axis ticks to display month names at regular intervals
            first_day_of_month_indices = df.index[df['Date Time, GMT-04:00'].dt.day == 1]
            plt.xticks(first_day_of_month_indices, [dt.strftime('%b') for dt in df.loc[first_day_of_month_indices, 'Date Time, GMT-04:00']], rotation=45, fontdict={'family': 'sans-serif', 'size': 25, 'style': 'normal'})
            
            plt.tight_layout()
            plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### Individual start and end time checks:
# This cell reports the start and end times from the dataframe and deployment metadata for a single file.

# %%
# %% Individual start time end time checks 
print("DataFrame Start Time:", df_files['TCBKIT']['2310']['a']['DataFrame']['Date Time, GMT-04:00'].iloc[0])
print("Deployment Data Start Time:", deployment_data_dict['BT_TCBKIT_2310_']['Date In Time In'])

# Print end time
print("DataFrame End Time:", df_files['TCBKIT']['2310']['a']['DataFrame']['Date Time, GMT-04:00'].iloc[-1])
print("Deployment Data End Time:", deployment_data_dict['BT_TCBKIT_2310_']['Date Out Time Out'])

# Then, check if the extracted timestamps match the expected start and end times.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 2
#       1 # %% Individual start time end time checks
# ----> 2 print("DataFrame Start Time:", df_files['TCBKIT']['2310']['a']['DataFrame']['Date Time, GMT-04:00'].iloc[0])
#       3 print("Deployment Data Start Time:", deployment_data_dict['BT_TCBKIT_2310_']['Date In Time In'])
#       5 # Print end time
#
# KeyError: '2310'

# %% [markdown]
# ### Start end time check loop:
# To see every start and end time from the dataframe and deployment metadata, run this cell. This allows you to see the listed start and end times as displaced in the deployment log vs the now editied start and edn times in the file.

# %%
# %% Loop for start time end time checks
# List to store the names of empty DataFrames
empty_dataframes = []

# Loop through each site code, file number, and file identifier in df_files
for site_code, site_data in df_files.items():
    for file_number, file_data in site_data.items():
        for file_identifier, file_info in file_data.items():
            # Get the DataFrame for the current file
            df = file_info['DataFrame']
            
            if not df.empty:  # Check if the DataFrame is not empty
                # Print the start and end times for the current DataFrame
                print(f"DataFrame Start Time ({site_code}_{file_number}_{file_identifier}):", df['Date Time, GMT-04:00'].iloc[0])
                print(f"DataFrame End Time ({site_code}_{file_number}_{file_identifier}):", df['Date Time, GMT-04:00'].iloc[-1])

                # Get the corresponding offloaded file name
                offloaded_file_name = file_info['File Name']
                
                # Retrieve deployment data using the offloaded file name
                deployment_data = deployment_data_dict.get(offloaded_file_name)
                
                if deployment_data:
                    # Print the start and end times from deployment data
                    print(f"Deployment Data Start Time ({offloaded_file_name}):", deployment_data['Date In Time In'])
                    print(f"Deployment Data End Time ({offloaded_file_name}):", deployment_data['Date Out Time Out'])
                else:
                    print(f"No deployment data found for {offloaded_file_name}")

                print()  # Add an empty line for better readability
            else:
                # If DataFrame is empty, append its name to the list
                empty_dataframes.append(f"{site_code}_{file_number}_{file_identifier}")

# Print names of empty DataFrames
if empty_dataframes:
    print("Names of empty DataFrames:")
    for name in empty_dataframes:
        print(name)
else:
    print("No empty DataFrames found.")
# Out:
# DataFrame Start Time (TCBKIT_2011_a): 2020-11-05 17:00:00
# DataFrame End Time (TCBKIT_2011_a): 2021-11-05 11:00:00
# Deployment Data Start Time (BT_TCBKIT_2011): 2020-11-05 15:58:00
# Deployment Data End Time (BT_TCBKIT_2011): 2021-11-05 12:27:00
#
# DataFrame Start Time (TCBKIX_2103_a): 2021-03-15 11:30:00
# DataFrame End Time (TCBKIX_2103_a): 2021-11-15 08:45:00
# Deployment Data Start Time (BT_TCBKIX_2103_a): 2021-03-15 10:30:00
# Deployment Data End Time (BT_TCBKIX_2103_a): 2021-11-15 10:12:00
#
# DataFrame Start Time (TCBKIX_2103_b): 2021-03-15 11:30:00
# DataFrame End Time (TCBKIX_2103_b): 2021-11-15 08:45:00
# Deployment Data Start Time (BT_TCBKIX_2103_b): 2021-03-15 10:30:00
# Deployment Data End Time (BT_TCBKIX_2103_b): 2021-11-15 10:12:00
#
# DataFrame Start Time (TCBKPT_2011_a): 2020-10-30 15:00:00
# DataFrame End Time (TCBKPT_2011_a): 2021-10-22 12:00:00
# Deployment Data Start Time (BT_TCBKPT_2011_a): 2020-10-30 13:51:00
# Deployment Data End Time (BT_TCBKPT_2011_a): 2021-10-22 13:28:00
#
# DataFrame Start Time (TCBKPT_2011_b): 2020-10-30 15:00:00
# DataFrame End Time (TCBKPT_2011_b): 2021-10-22 12:00:00
# Deployment Data Start Time (BT_TCBKPT_2011_b): 2020-10-30 13:51:00
# Deployment Data End Time (BT_TCBKPT_2011_b): 2021-10-22 13:28:00
#
# DataFrame Start Time (TCBOTB_2011_a): 2020-11-24 14:45:00
# DataFrame End Time (TCBOTB_2011_a): 2021-10-18 12:00:00
# Deployment Data Start Time (BT_TCBOTB_2011): 2020-11-24 13:41:00
# Deployment Data End Time (BT_TCBOTB_2011): 2021-10-18 13:15:00
#
# DataFrame Start Time (TCBRWB_2011_a): 2020-11-05 16:30:00
# DataFrame End Time (TCBRWB_2011_a): 2021-10-22 10:45:00
# Deployment Data Start Time (BT_TCBRWB_2011): 2020-11-05 15:27:00
# Deployment Data End Time (BT_TCBRWB_2011): 2021-10-22 12:12:00
#
# DataFrame Start Time (TCCB08_2104_a): 2021-04-06 12:45:00
# DataFrame End Time (TCCB08_2104_a): 2021-11-16 10:45:00
# Deployment Data Start Time (BT_TCCB08_2104_a): 2021-04-06 11:33:00
# Deployment Data End Time (BT_TCCB08_2104_a): 2021-11-16 12:03:00
#
# DataFrame Start Time (TCCB08_2104_b): 2021-04-06 12:45:00
# DataFrame End Time (TCCB08_2104_b): 2021-11-16 10:45:00
# Deployment Data Start Time (BT_TCCB08_2104_b): 2021-04-06 11:33:00
# Deployment Data End Time (BT_TCCB08_2104_b): 2021-11-16 12:03:00
#
# DataFrame Start Time (TCCB40_2104_a): 2021-04-06 11:45:00
# DataFrame End Time (TCCB40_2104_a): 2021-11-16 09:45:00
# Deployment Data Start Time (BT_TCCB40_2104_a): 2021-04-06 10:38:00
# Deployment Data End Time (BT_TCCB40_2104_a): 2021-11-16 11:03:00
#
# DataFrame Start Time (TCCB40_2104_b): 2021-04-06 11:45:00
# DataFrame End Time (TCCB40_2104_b): 2021-11-16 09:45:00
# Deployment Data Start Time (BT_TCCB40_2104_b): 2021-04-06 10:38:00
# Deployment Data End Time (BT_TCCB40_2104_b): 2021-11-16 11:03:00
#
# DataFrame Start Time (TCCLGE_2012_a): 2020-12-04 16:30:00
# DataFrame End Time (TCCLGE_2012_a): 2021-12-03 12:45:00
# Deployment Data Start Time (BT_TCCLGE_2012): 2020-12-04 15:30:00
# Deployment Data End Time (BT_TCCLGE_2012): 2021-12-03 14:10:00
#
# DataFrame Start Time (TCCORB_2012_a): 2020-12-10 14:30:00
# DataFrame End Time (TCCORB_2012_a): 2021-10-19 09:30:00
# Deployment Data Start Time (BT_TCCORB_2012): 2020-12-10 13:25:00
# Deployment Data End Time (BT_TCCORB_2012): 2021-10-19 10:45:00
#
# DataFrame Start Time (TCCORK_2011_a): 2020-12-14 15:00:00
# DataFrame Start Time (TCSR30_2104_a): 2021-04-08 11:00:00
# DataFrame End Time (TCSR30_2104_a): 2021-11-13 10:15:00
# Deployment Data Start Time (BT_TCSR30_2104_): 2021-04-08 09:55:00
# Deployment Data End Time (BT_TCSR30_2104_): 2021-11-13 11:37:00
#
# DataFrame Start Time (TCSR41_2104_a): 2021-04-08 11:00:00
# DataFrame End Time (TCSR41_2104_a): 2021-11-13 10:15:00
# Deployment Data Start Time (BT_TCSR41_2104_a): 2021-04-08 09:55:00
# Deployment Data End Time (BT_TCSR41_2104_a): 2021-11-13 11:44:00
#
# DataFrame Start Time (TCSR41_2104_b): 2021-04-08 11:00:00
# DataFrame End Time (TCSR41_2104_b): 2021-11-13 10:15:00
# Deployment Data Start Time (BT_TCSR41_2104_b): 2021-04-08 09:55:00
# Deployment Data End Time (BT_TCSR41_2104_b): 2021-11-13 11:44:00
#
# DataFrame Start Time (TCSWAT_2012_a): 2020-12-14 11:00:00
# DataFrame End Time (TCSWAT_2012_a): 2021-11-04 09:30:00
# Deployment Data Start Time (BT_TCSWAT_2012): 2020-12-14 09:55:00
# Deployment Data End Time (BT_TCSWAT_2012): 2021-11-04 10:55:00
#
# No empty DataFrames found.

# %% [markdown]
# ## <u>Trimmed file dates </u>
# This loop iterates through the .csv files for each site and reports the first and last sample dates. This will make it easier to report the trimmed file dates in the metadata and deployment log as the code names for the files are based on their trimmed dates, making the metadata inconsistent for several files. The days are also included as the day is needed for the DATASET files for the metadata part of the SOP.

# %%
# Iterate through df_files to extract and save the "a" version of the files
for site_code, site_data in df_files.items():
    for file_number, file_data in site_data.items():
        if 'a' in file_data:  # Check if "a" version exists for the file
            # Extract the DataFrame for the "a" version
            df_a = file_data['a']['DataFrame']
            
            # Get the year and month of the first and last data points
            first_data_point = df_a['Date Time, GMT-04:00'].iloc[0]
            last_data_point = df_a['Date Time, GMT-04:00'].iloc[-1]
            year_month_first = first_data_point.strftime("%y %m %d")  # Using last two digits of the year
            year_month_last = last_data_point.strftime("%y %m %d")    # Using last two digits of the year
            
            # Construct the base file name
            base_file_name = f"BT_{site_code}_{year_month_first}_{year_month_last}"
            
            # Check if the file is identified as a calculation file
            if (site_code, file_number) in calculations:
                output_file_name = f"{base_file_name}_calculations.csv"
            else:
                output_file_name = f"{base_file_name}.csv"
            
            print(f"{output_file_name}")
        else:
            print(f"No 'a' version found for Site: {site_code}, File Number: {file_number}")
# Out:
# BT_TCBKIT_20 11 05_21 11 05.csv
# BT_TCBKIX_21 03 15_21 11 15.csv
# BT_TCBKPT_20 10 30_21 10 22.csv
# BT_TCBOTB_20 11 24_21 10 18.csv
# BT_TCBRWB_20 11 05_21 10 22.csv
# BT_TCCB08_21 04 06_21 11 16.csv
# BT_TCCB40_21 04 06_21 11 16.csv
# BT_TCCLGE_20 12 04_21 12 03.csv
# BT_TCCORB_20 12 10_21 10 19.csv
# BT_TCCORK_20 12 14_21 10 19.csv
# BT_TCCSTL_21 04 07_21 11 14.csv
# BT_TCEAGR_21 04 07_21 11 15.csv
# BT_TCFLTC_20 10 30_21 10 22.csv
# BT_TCFSHB_20 12 10_21 10 19.csv
# BT_TCGMKT_20 12 07_21 11 29.csv
# BT_TCGRPD_21 03 13_21 11 14.csv
# BT_TCHB40_20 12 04_21 12 03.csv
# BT_TCJCKB_21 04 07_21 11 11.csv
# BT_TCKNGC_21 03 14_21 11 12.csv
# BT_TCLBEM_21 03 13_21 11 14.csv
# BT_TCLBRH_21 03 12_21 11 22.csv
# BT_TCLSTJ_20 11 05_21 11 04.csv
# BT_TCMAGB_20 11 24_21 10 18.csv
# BT_TCMERI_20 12 10_21 11 09.csv
# BT_TCMT24_21 03 14_21 11 12.csv
# BT_TCMT40_21 03 14_21 11 12_calculations.csv
# BT_TCSAVA_20 11 24_21 10 18.csv
# BT_TCSC35_20 12 08_21 11 30.csv
# BT_TCSCAP_20 12 08_21 11 04.csv
# BT_TCSHCS_20 12 08_21 11 05.csv
# BT_TCSPTH_21 03 14_21 11 12.csv
# BT_TCSR30_21 04 08_21 11 13.csv
# BT_TCSR41_21 04 08_21 11 13.csv
# BT_TCSWAT_20 12 14_21 11 04.csv

# %% [markdown]
# ## <b>Step 2 and 3. Offload data and file naming conventions

# %% [markdown]
# ### Setting output folder and exporting the .csv files:
# This cell defines the output folder, creating the folder if not existing previously, then runs a loop, first checking for the a version of the file and then extracting that data frame to export the .csv files by the naming convention set in the SOP as BT_site_code_year_month_first_year_month_last. Inside the loop also checks if the file was identified as "calculations", if so then adds "_calculations.csv" as is the naming convention set for them in the SOP. Internal calculations offloads the files that have the temperature columns averaged and empty cells to show the number of instances where there was a difference >0.2 and will not be uploaded to the drive.
# <li><u>Make sure to update the folder path in the cell!</u>

# %%
# Define the output folder where you want to save the extracted files
output_folder = r"C:\UVI\QAQC stuff\Temp_TCRMP_2021_Output"

# Define the internal calculations folder within the output folder
internal_calculations_folder = os.path.join(output_folder, "internal_calculations")

# Create the calculations folder if it doesn't exist
if not os.path.exists(internal_calculations_folder):
    os.makedirs(internal_calculations_folder)

# Iterate through df_files to extract and save the "a" version of the files
for site_code, site_data in df_files.items():
    for file_number, file_data in site_data.items():
        if 'a' in file_data:  # Check if "a" version exists for the file
            # Extract the DataFrame for the "a" version
            df_a = file_data['a']['DataFrame']
            
            # Get the year and month of the first and last data points
            first_data_point = df_a['Date Time, GMT-04:00'].iloc[0]
            last_data_point = df_a['Date Time, GMT-04:00'].iloc[-1]
            year_month_first = first_data_point.strftime("%y%m")  # Using last two digits of the year
            year_month_last = last_data_point.strftime("%y%m")    # Using last two digits of the year
            
            # Construct the base file name
            base_file_name = f"BT_{site_code}_{year_month_first}_{year_month_last}"
            
            # Check if the file is identified as a calculation file
            if (site_code, file_number) in calculations:
                output_file_name = f"{base_file_name}_internal_calculations.csv"
                output_file_path = os.path.join(internal_calculations_folder, output_file_name)
            else:
                output_file_name = f"{base_file_name}.csv"
                output_file_path = os.path.join(output_folder, output_file_name)
            
            # Save the DataFrame to CSV
            df_a.to_csv(output_file_path, index=False)
            
            print(f"File saved: {output_file_path}")
        else:
            print(f"No 'a' version found for Site: {site_code}, File Number: {file_number}")
# Out:
# File saved: C:\UVI\QAQC stuff\Temp_TCRMP_2021_Output\BT_TCBKIT_2011_2111.csv
# File saved: C:\UVI\QAQC stuff\Temp_TCRMP_2021_Output\BT_TCBKIX_2103_2111.csv
# File saved: C:\UVI\QAQC stuff\Temp_TCRMP_2021_Output\BT_TCBKPT_2010_2110.csv
# File saved: C:\UVI\QAQC stuff\Temp_TCRMP_2021_Output\BT_TCBOTB_2011_2110.csv
# File saved: C:\UVI\QAQC stuff\Temp_TCRMP_2021_Output\BT_TCBRWB_2011_2110.csv
# File saved: C:\UVI\QAQC stuff\Temp_TCRMP_2021_Output\BT_TCCB08_2104_2111.csv
# File saved: C:\UVI\QAQC stuff\Temp_TCRMP_2021_Output\BT_TCCB40_2104_2111.csv
# File saved: C:\UVI\QAQC stuff\Temp_TCRMP_2021_Output\BT_TCCLGE_2012_2112.csv
# File saved: C:\UVI\QAQC stuff\Temp_TCRMP_2021_Output\BT_TCCORB_2012_2110.csv
# File saved: C:\UVI\QAQC stuff\Temp_TCRMP_2021_Output\BT_TCCORK_2012_2110.csv
# File saved: C:\UVI\QAQC stuff\Temp_TCRMP_2021_Output\BT_TCCSTL_2104_2111.csv
# File saved: C:\UVI\QAQC stuff\Temp_TCRMP_2021_Output\BT_TCEAGR_2104_2111.csv
# File saved: C:\UVI\QAQC stuff\Temp_TCRMP_2021_Output\BT_TCFLTC_2010_2110.csv
# File saved: C:\UVI\QAQC stuff\Temp_TCRMP_2021_Output\BT_TCFSHB_2012_2110.csv
# File saved: C:\UVI\QAQC stuff\Temp_TCRMP_2021_Output\BT_TCGMKT_2012_2111.csv
# File saved: C:\UVI\QAQC stuff\Temp_TCRMP_2021_Output\BT_TCGRPD_2103_2111.csv
# File saved: C:\UVI\QAQC stuff\Temp_TCRMP_2021_Output\BT_TCHB40_2012_2112.csv
# File saved: C:\UVI\QAQC stuff\Temp_TCRMP_2021_Output\BT_TCJCKB_2104_2111.csv
# File saved: C:\UVI\QAQC stuff\Temp_TCRMP_2021_Output\BT_TCKNGC_2103_2111.csv
# File saved: C:\UVI\QAQC stuff\Temp_TCRMP_2021_Output\BT_TCLBEM_2103_2111.csv
# File saved: C:\UVI\QAQC stuff\Temp_TCRMP_2021_Output\BT_TCLBRH_2103_2111.csv
# File saved: C:\UVI\QAQC stuff\Temp_TCRMP_2021_Output\BT_TCLSTJ_2011_2111.csv
# File saved: C:\UVI\QAQC stuff\Temp_TCRMP_2021_Output\BT_TCMAGB_2011_2110.csv
# File saved: C:\UVI\QAQC stuff\Temp_TCRMP_2021_Output\BT_TCMERI_2012_2111.csv
# File saved: C:\UVI\QAQC stuff\Temp_TCRMP_2021_Output\BT_TCMT24_2103_2111.csv
# File saved: C:\UVI\QAQC stuff\Temp_TCRMP_2021_Output\internal_calculations\BT_TCMT40_2103_2111_internal_calculations.csv
# File saved: C:\UVI\QAQC stuff\Temp_TCRMP_2021_Output\BT_TCSAVA_2011_2110.csv
# File saved: C:\UVI\QAQC stuff\Temp_TCRMP_2021_Output\BT_TCSC35_2012_2111.csv
# File saved: C:\UVI\QAQC stuff\Temp_TCRMP_2021_Output\BT_TCSCAP_2012_2111.csv
# File saved: C:\UVI\QAQC stuff\Temp_TCRMP_2021_Output\BT_TCSHCS_2012_2111.csv
# File saved: C:\UVI\QAQC stuff\Temp_TCRMP_2021_Output\BT_TCSPTH_2103_2111.csv
# File saved: C:\UVI\QAQC stuff\Temp_TCRMP_2021_Output\BT_TCSR30_2104_2111.csv
# File saved: C:\UVI\QAQC stuff\Temp_TCRMP_2021_Output\BT_TCSR41_2104_2111.csv
# File saved: C:\UVI\QAQC stuff\Temp_TCRMP_2021_Output\BT_TCSWAT_2012_2111.csv

# %% [markdown]
# ### Offload loop: a and merged data
# The code below is to test for files that were named using 'a' or 'merged' identifiers. It will loop through the .csv files and export them if they match those identifiers.<u>This has not been tested<u>

# %%
# %% This is a TEST to handle exporting both the "a" and "merged" identifiers
# # Iterate through df_files to extract and save the "a" and "merged" versions of the files
# for site_code, site_data in df_files.items():
#     for file_number, file_data in site_data.items():
#         for identifier, data_info in file_data.items():
#             if identifier in ['a', 'merged']:  # Check if the identifier is either 'a' or 'merged'
#                 # Extract the DataFrame for the current identifier
#                 df = data_info['DataFrame']
                
#                 # Get the year and month of the first and last data points
#                 first_data_point = df['Date Time, GMT-04:00'].iloc[0]
#                 last_data_point = df['Date Time, GMT-04:00'].iloc[-1]
#                 year_month_first = first_data_point.strftime("%y%m")  # Using last two digits of the year
#                 year_month_last = last_data_point.strftime("%y%m")    # Using last two digits of the year
                
#                 # Construct the base file name
#                 base_file_name = f"BT_{site_code}_{year_month_first}_{year_month_last}"
                
#                 # Check if the file is identified as a calculation file
#                 if (site_code, file_number) in calculations:
#                     output_file_name = f"{base_file_name}_calculations.csv"
#                 else:
#                     output_file_name = f"{base_file_name}.csv"
                
#                 output_file_path = os.path.join(output_folder, output_file_name)
                
#                 # Save the DataFrame to CSV
#                 df.to_csv(output_file_path, index=False)
                
#                 print(f"File saved: {output_file_path}")
#             else:
#                 print(f"No 'a' or 'merged' version found for Site: {site_code}, File Number: {file_number}")

# %% [markdown]
# ### Offloading plots: only a files
# Code below reads in the newly offloaded csv files, converts the date time, and plots the temperature over time for each .csv file then exports them to a folder.
# <li><u>To save the plots, you will need to create a directory (a folder). Make sure to update that folder path in the save_dir = part of the cell!</u>

# %%
#%% Using new offloaded files create plots and save plots to a folder
 
exported_folder_path = r'C:\UVI\QAQC stuff\Temp_TCRMP_2021_Output'

# Define pattern to match CSV files
file_pattern = '*.csv'

# Use glob to get a list of file paths matching the pattern set in file_pattern
exported_csv_files = glob.glob(exported_folder_path + '/' + file_pattern)

# Loop through each CSV file
for csv_file in exported_csv_files:
    # Read the CSV file into a pandas DataFrame
    df = pd.read_csv(csv_file)
    
    df['Date Time, GMT-04:00'] = pd.to_datetime(df['Date Time, GMT-04:00'], format='%Y-%m-%d %H:%M:%S')

    # Convert the 'Date Time, GMT-04:00' column to datetime format
    #df.loc[:, 'Date Time, GMT-04:00'] = pd.to_datetime(df['Date Time, GMT-04:00'])
    df['Date Time, GMT-04:00'] = pd.to_datetime(df['Date Time, GMT-04:00'])
    # Plot the data
    plt.figure(figsize=(12, 6))
    plt.plot(df['Date Time, GMT-04:00'], df['Temp, °C'], color='blue', marker='o', linestyle='-')
    plt.title('Temperature Over Time')
    plt.xlabel('Date Time')
    plt.ylabel('Temp, °C')
    plt.grid(True)
    
    # Set x-axis ticks to display month names at regular intervals
    # first_day_of_month_indices = df.index[df['Date Time, GMT-04:00'].dt.day == 1]
    # plt.xticks(first_day_of_month_indices, [dt.strftime('%b') for dt in df.loc[first_day_of_month_indices, 'Date Time, GMT-04:00']], rotation=45, fontdict={'family': 'sans-serif', 'size': 25, 'style': 'normal'})
    plt.xticks(rotation=45)
    plt.tight_layout()
    
    # Extract file name from the file path
    file_name = os.path.basename(csv_file)
    
    # Define the file name for the plot
    plot_file_name = os.path.splitext(file_name)[0] + '_plot.png'
    
    save_dir = r"C:\UVI\QAQC stuff\Temp_TCRMP_2024_Output\graphs"
    # Save the plot
    plt.savefig(os.path.join(save_dir, plot_file_name))
    
    # Show the plot (optional)
    # plt.show()
# Out:
# C:\Users\magic\AppData\Local\Temp\ipykernel_10992\2958653286.py:22: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(12, 6))

# %% [markdown]
# ### Offload loop: a and merged plots
# This loops through the .csv files and generates plots for 'a' or 'merged' identified files and generates then exports the plots.

# %%
#%%
# # Loop through df_files and plot graphs for each DataFrame where time is displayed as year and month
# for site_code, site_data in df_files.items():
#     for file_number, file_data in site_data.items():
#         for file_identifier, file_info in file_data.items():
#             # Check if the file_identifier starts with 'a' or is 'merged'
#             if file_identifier.startswith('a') or file_identifier == 'merged':
#                 # Get the DataFrame
#                 df = file_info['DataFrame']

#                 # Convert the 'Date Time, GMT-04:00' column to datetime format
#                 df.loc[:, 'Date Time, GMT-04:00'] = pd.to_datetime(df['Date Time, GMT-04:00'])

#                 # Plot the temperature over time
#                 plt.figure(figsize=(12, 6))
#                 plt.plot(df.index, df['Temp, °C'], color='blue', marker='o', linestyle='-')
#                 plt.title(f'Temperature Over Time - Site: {site_code}, File Number: {file_number}, Identifier: {file_identifier}')
#                 plt.xlabel('Date Time')
#                 plt.ylabel('Temp, °C')
#                 plt.grid(True)
                
#                 # Set x-axis ticks to display month names at regular intervals
#                 first_day_of_month_indices = df.index[df['Date Time, GMT-04:00'].dt.day == 1]
#                 plt.xticks(first_day_of_month_indices, [dt.strftime('%b') for dt in df.loc[first_day_of_month_indices, 'Date Time, GMT-04:00']], rotation=45, fontdict={'family': 'sans-serif', 'size': 25, 'style': 'normal'})
                
#                 plt.tight_layout()
                
#                 # Specify the directory to save the images
#                 save_dir = r"C:\Users\900094088\Documents\Oceanography\SOPs\HOBO SOPs\Export_folder\graphs"
#                 if not os.path.exists(save_dir):
#                     os.makedirs(save_dir)
                
#                 # Define the file name
#                 file_name = f"temp_over_time_{site_code}_{file_number}_{file_identifier}.png"
                
#                 # Save the plot as an image file
#                 plt.savefig(os.path.join(save_dir, file_name), dpi=300)
                
#                 # Close the plot to free up memory
#                 plt.close()
